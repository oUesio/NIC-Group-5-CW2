# %%
import math
import random
from typing import List, Dict, Any, Tuple
import numpy as np

# ============================================================
# CONFIG
# ============================================================
INSTANCE_PATH = r"C:\MDU\Masters\Nature Inspired\Group Project\Group 5\gecco19-thief\src\main\resources\a280-n279.txt"

RNG_SEED = 0
random.seed(RNG_SEED)
np.random.seed(RNG_SEED)

# Candidate list size
CAND_K = 3000

# Multi-start + ILS parameters
NUM_STARTS = 30           # how many different initial tours
ILS_RESTARTS = 200         # double-bridge kicks per best tour basin

# Local search parameters
TWO_OPT_MAX_ITERS = 10000          # per LS call
THREE_OPT_TRIES_PER_LS = 20000    # random 3-opt attempts per LS call

VERBOSE = True


# ============================================================
# TTP PARSER (simple, as in your LKH-lite)
# ============================================================
def parse_ttp(path: str) -> Dict[str, Any]:
    with open(path, "r") as f:
        lines = [line.strip() for line in f if line.strip()]

    dim = num_items = capacity = v_min = v_max = None
    edge_type = None

    i = 0
    while i < len(lines):
        L = lines[i]
        if L.startswith("DIMENSION"):
            dim = int(L.split(":")[1])
        elif L.startswith("NUMBER OF ITEMS"):
            num_items = int(L.split(":")[1])
        elif L.startswith("CAPACITY OF KNAPSACK"):
            capacity = float(L.split(":")[1])
        elif L.startswith("MIN SPEED"):
            v_min = float(L.split(":")[1])
        elif L.startswith("MAX SPEED"):
            v_max = float(L.split(":")[1])
        elif L.startswith("EDGE_WEIGHT_TYPE"):
            edge_type = L.split(":")[1].strip()
        elif L.startswith("NODE_COORD_SECTION"):
            break
        i += 1

    if dim is None:
        raise RuntimeError("DIMENSION not found in TTP file.")
    if edge_type is None:
        raise RuntimeError("EDGE_WEIGHT_TYPE not found in TTP file.")

    i += 1
    coords = np.zeros((dim, 2))
    for k in range(dim):
        idx, x, y = lines[i + k].split()
        coords[int(idx) - 1] = [float(x), float(y)]
    i += dim

    # Items (not needed for pure TSP, but we parse anyway)
    while i < len(lines) and "ITEMS SECTION" not in lines[i]:
        i += 1
    i += 1

    profits = np.zeros(num_items)
    weights = np.zeros(num_items)
    city = np.zeros(num_items, int)
    for j in range(num_items):
        p = lines[i + j].split()
        profits[j] = float(p[1])
        weights[j] = float(p[2])
        city[j] = int(p[3]) - 1

    return dict(
        dim=dim,
        coords=coords,
        items_profit=profits,
        items_weight=weights,
        items_city=city,
        capacity=capacity,
        v_min=v_min,
        v_max=v_max,
        edge_type=edge_type,
    )


# ============================================================
# DISTANCES + CANDIDATE LISTS
# ============================================================
def build_distance_matrix(coords: np.ndarray, edge: str):
    """
    TSPLIB-style distances.

    - EUC_2D:  int( sqrt(dx^2 + dy^2) + 0.5 )
    - CEIL_2D: int( ceil( sqrt(dx^2 + dy^2) ) )
    - else:    raw Euclidean as float
    """
    n = len(coords)
    edge = edge.upper() if edge else ""

    dist = [[0] * n for _ in range(n)]
    for i in range(n):
        xi, yi = coords[i]
        for j in range(i + 1, n):
            xj, yj = coords[j]
            dx = xi - xj
            dy = yi - yj
            dij = math.sqrt(dx * dx + dy * dy)

            if edge.startswith("EUC_2D"):
                dij = int(dij + 0.5)
            elif edge.startswith("CEIL_2D"):
                dij = int(math.ceil(dij))
            # else leave float

            dist[i][j] = dist[j][i] = dij

    return dist


def build_candidate_lists(dist, k: int):
    n = len(dist)
    C = []
    for i in range(n):
        nbr = sorted([(dist[i][j], j) for j in range(n) if j != i])[:k]
        C.append([j for _, j in nbr])
    return C


# ============================================================
# BASIC UTILITIES
# ============================================================
def tour_length(tour: List[int], dist) -> float:
    return sum(dist[tour[i]][tour[(i + 1) % len(tour)]] for i in range(len(tour)))


def check_permutation(tour: List[int], n: int):
    assert len(tour) == n, f"tour length {len(tour)} != {n}"
    s = set(tour)
    assert s == set(range(n)), f"tour not permutation of 0..{n-1}"


def ensure_valid(tour: List[int], n: int) -> List[int]:
    """Repair tour to a valid permutation, starting at 0."""
    seen = set()
    cleaned = []
    for c in tour:
        if 0 <= c < n and c not in seen:
            cleaned.append(c)
            seen.add(c)
    for c in range(n):
        if c not in seen:
            cleaned.append(c)
            seen.add(c)
    if 0 in cleaned:
        k = cleaned.index(0)
        cleaned = cleaned[k:] + cleaned[:k]
    else:
        cleaned = [0] + [c for c in range(1, n)]
    return cleaned[:n]


def nearest_neighbor_tour(dist, start: int = 0) -> List[int]:
    n = len(dist)
    unv = set(range(n))
    unv.remove(start)
    t = [start]
    cur = start
    while unv:
        nxt = min(unv, key=lambda j: dist[cur][j])
        t.append(nxt)
        unv.remove(nxt)
        cur = nxt
    return t


def random_greedy_tour(dist, cand, alpha: float = 0.3) -> List[int]:
    """
    Randomised greedy: at each step choose among a few nearest neighbours
    (RCL of size ~alpha * |cand[i]|).
    """
    n = len(dist)
    start = 0
    unv = set(range(n))
    unv.remove(start)
    t = [start]
    cur = start

    while unv:
        neigh = [j for j in cand[cur] if j in unv]
        if not neigh:
            # fallback: any remaining
            neigh = list(unv)
        neigh = sorted(neigh, key=lambda j: dist[cur][j])
        rcl_size = max(1, int(len(neigh) * alpha))
        rcl = neigh[:rcl_size]
        nxt = random.choice(rcl)
        t.append(nxt)
        unv.remove(nxt)
        cur = nxt

    return t


# ============================================================
# 2-OPT LOCAL SEARCH (candidate-guided)
# ============================================================
def two_opt_cand(tour: List[int], dist, cand, max_iter: int = 1000, label: str = "") -> Tuple[List[int], float]:
    n = len(tour)
    pos = [0] * n
    for i, c in enumerate(tour):
        pos[c] = i

    best_len = tour_length(tour, dist)
    if VERBOSE:
        print(f"[2-OPT{label}] start={best_len:.2f}")

    it = 0
    improved = True
    while improved and it < max_iter:
        improved = False
        it += 1

        for i in range(n):
            a = tour[i]
            b = tour[(i + 1) % n]

            for c in cand[a]:
                j = pos[c]
                if j <= i + 1 or j >= n - 1:
                    continue
                d = tour[(j + 1) % n]

                old = dist[a][b] + dist[c][d]
                new = dist[a][c] + dist[b][d]

                if new < old:
                    # apply 2-opt reversal
                    if i + 1 <= j:
                        tour[i + 1 : j + 1] = reversed(tour[i + 1 : j + 1])
                    else:
                        continue  # shouldn't happen with j>i+1

                    # update pos
                    for k, x in enumerate(tour):
                        pos[x] = k

                    best_len = tour_length(tour, dist)
                    if VERBOSE and it % 50 == 0:
                        print(f"[2-OPT{label}] it={it} len={best_len:.2f}")
                    improved = True
                    break

            if improved:
                break

    if VERBOSE:
        print(f"[2-OPT{label}] final={best_len:.2f}")
    return tour, best_len


# ============================================================
# RANDOM 3-OPT (subset of moves, sampled)
# ============================================================
def try_three_opt_move(
    tour: List[int],
    dist,
    i: int,
    j: int,
    k: int,
) -> Tuple[bool, List[int], float]:
    """
    Try a subset of 3-opt reconnections on segments:
    [0..i], [i+1..j], [j+1..k], [k+1..end]
    Returns (improved?, new_tour, new_length)
    """
    n = len(tour)
    a, b = tour[i], tour[(i + 1) % n]
    c, d = tour[j], tour[(j + 1) % n]
    e, f = tour[k], tour[(k + 1) % n]

    base = dist[a][b] + dist[c][d] + dist[e][f]

    # Pre-split
    s1 = tour[: i + 1]
    s2 = tour[i + 1 : j + 1]
    s3 = tour[j + 1 : k + 1]
    s4 = tour[k + 1 :]

    best_delta = 0.0
    best_tour = None

    # Move type 1: reverse s2
    cand1 = s1 + list(reversed(s2)) + s3 + s4
    d1 = (
        dist[a][tour[j]]
        + dist[tour[i + 1]][d]
        + dist[e][f]
    )
    delta1 = d1 - base
    if delta1 < best_delta:
        best_delta = delta1
        best_tour = cand1

    # Move type 2: reverse s3
    cand2 = s1 + s2 + list(reversed(s3)) + s4
    d2 = (
        dist[a][b]
        + dist[c][tour[k]]
        + dist[tour[j + 1]][f]
    )
    delta2 = d2 - base
    if delta2 < best_delta:
        best_delta = delta2
        best_tour = cand2

    # Move type 3: reverse s2 and s3
    cand3 = s1 + list(reversed(s2)) + list(reversed(s3)) + s4
    d3 = (
        dist[a][tour[j]]
        + dist[tour[i + 1]][tour[k]]
        + dist[tour[j + 1]][f]
    )
    delta3 = d3 - base
    if delta3 < best_delta:
        best_delta = delta3
        best_tour = cand3

    # Move type 4: swap s2 and s3 (no reversals)
    cand4 = s1 + s3 + s2 + s4
    d4 = (
        dist[a][c]
        + dist[e][b]
        + dist[tour[j]][f]
    )
    delta4 = d4 - base
    if delta4 < best_delta:
        best_delta = delta4
        best_tour = cand4

    if best_tour is not None and best_delta < 0:
        new_len = tour_length(best_tour, dist)
        return True, best_tour, new_len
    else:
        return False, tour, tour_length(tour, dist)


def three_opt_random(
    tour: List[int],
    dist,
    cand,
    tries: int = 10000,
    label: str = "",
) -> Tuple[List[int], float]:
    """
    Random 3-opt: sample triples (i,j,k) with candidate guidance.
    """
    n = len(tour)
    best_len = tour_length(tour, dist)
    if VERBOSE:
        print(f"[3-OPT{label}] start={best_len:.2f}")

    pos = [0] * n
    for idx, c in enumerate(tour):
        pos[c] = idx

    improved_any = False

    for t in range(tries):
        # pick random anchor city
        i = random.randint(0, n - 1)
        a = tour[i]

        # pick neighbor candidate for a
        cand_neighbors = cand[a]
        if not cand_neighbors:
            continue
        c1 = random.choice(cand_neighbors)
        j = pos[c1]

        # maintain ordering i < j < k in index space by rotating if needed
        if j == i or (j + 1) % n == i:
            continue

        # pick second anchor from neighbors of city at j
        bcity = tour[j]
        cand_neighbors2 = cand[bcity]
        if not cand_neighbors2:
            continue
        c2 = random.choice(cand_neighbors2)
        k = pos[c2]

        # ensure distinct, and choose ordering in index space
        idxs = sorted([i, j, k])
        i2, j2, k2 = idxs[0], idxs[1], idxs[2]
        if i2 == j2 or j2 == k2:
            continue

        changed, new_tour, new_len = try_three_opt_move(tour, dist, i2, j2, k2)
        if changed and new_len < best_len:
            tour = new_tour
            best_len = new_len
            improved_any = True

            # update pos after accepted move
            pos = [0] * n
            for idx, c in enumerate(tour):
                pos[c] = idx

            if VERBOSE and (t + 1) % 1000 == 0:
                print(f"[3-OPT{label}] t={t+1} len={best_len:.2f}")

    if VERBOSE:
        print(f"[3-OPT{label}] final={best_len:.2f} (improved={improved_any})")
    return tour, best_len


# ============================================================
# DOUBLE-BRIDGE KICK (ILS PERTURBATION)
# ============================================================
def double_bridge_move(tour: List[int]) -> List[int]:
    n = len(tour)
    if n < 8:
        return tour[:]
    cuts = sorted(random.sample(range(1, n), 4))
    a, b, c, d = cuts
    s1 = tour[0:a]
    s2 = tour[a:b]
    s3 = tour[b:c]
    s4 = tour[c:d]
    s5 = tour[d:]
    return s1 + s3 + s2 + s4 + s5


# ============================================================
# LK-FLAVOURED MULTI-START + ILS
# ============================================================
def lk_style_tsp_from_ttp(
    data: Dict[str, Any],
    cand_k: int = CAND_K,
    num_starts: int = NUM_STARTS,
    ils_restarts: int = ILS_RESTARTS,
) -> Tuple[List[int], float, Any]:
    coords = data["coords"]
    edge = data["edge_type"]
    n = len(coords)

    print(f"[INFO] EDGE_WEIGHT_TYPE = {edge}")
    print("[DIST] Building distance matrix...")
    dist = build_distance_matrix(coords, edge)

    print(f"[CAND] Building candidate lists (k={cand_k})...")
    cand = build_candidate_lists(dist, cand_k)

    # --------------------------------------------------------
    # INITIAL TOURS (multi-start)
    # --------------------------------------------------------
    best_global_tour = None
    best_global_len = float("inf")

    for s in range(num_starts):
        print(f"\n[START {s+1}/{num_starts}] constructing initial tour...")

        if s == 0:
            base_tour = nearest_neighbor_tour(dist, start=0)
            base_tour = ensure_valid(base_tour, n)
        else:
            base_tour = random_greedy_tour(dist, cand, alpha=0.3)
            base_tour = ensure_valid(base_tour, n)

        base_len = tour_length(base_tour, dist)
        print(f"[BASE {s+1}] initial length={base_len:.2f}")

        # First pass: strong 2-opt
        tour_ls, len_ls = two_opt_cand(
            base_tour,
            dist,
            cand,
            max_iter=TWO_OPT_MAX_ITERS,
            label=f" S{s+1}"
        )

        # Then random 3-opt to deepen basin
        tour_ls, len_ls = three_opt_random(
            tour_ls,
            dist,
            cand,
            tries=THREE_OPT_TRIES_PER_LS,
            label=f" S{s+1}"
        )

        print(f"[BASIN {s+1}] local min length={len_ls:.2f}")

        # ----------------------------------------------------
        # ILS with double-bridge + local search again
        # ----------------------------------------------------
        best_basin_tour = tour_ls[:]
        best_basin_len = len_ls

        for r in range(ils_restarts):
            print(f"[ILS S{s+1}] restart {r+1}/{ils_restarts}")
            kicked = double_bridge_move(best_basin_tour)
            kicked = ensure_valid(kicked, n)

            k_len = tour_length(kicked, dist)
            if VERBOSE:
                print(f"[ILS S{s+1}] kicked length={k_len:.2f}")

            # local search again from kicked point
            kicked, k_len = two_opt_cand(
                kicked,
                dist,
                cand,
                max_iter=TWO_OPT_MAX_ITERS // 2,
                label=f" S{s+1}R{r+1}"
            )
            kicked, k_len = three_opt_random(
                kicked,
                dist,
                cand,
                tries=THREE_OPT_TRIES_PER_LS // 2,
                label=f" S{s+1}R{r+1}"
            )

            if k_len < best_basin_len:
                print(f"[ILS S{s+1}] improved basin {best_basin_len:.2f} -> {k_len:.2f}")
                best_basin_len = k_len
                best_basin_tour = kicked[:]
            else:
                print(f"[ILS S{s+1}] no improvement ({k_len:.2f} >= {best_basin_len:.2f})")

        # Update global best
        if best_basin_len < best_global_len:
            print(f"[GLOBAL] improved {best_global_len:.2f} -> {best_basin_len:.2f}")
            best_global_len = best_basin_len
            best_global_tour = best_basin_tour[:]

    # Final sanity checks
    check_permutation(best_global_tour, n)
    true_len = tour_length(best_global_tour, dist)
    print(f"\n[RESULT] best length={best_global_len:.2f}")
    print(f"[CHECK] tour_length(best)={true_len:.2f}")

    return best_global_tour, best_global_len, dist


# ============================================================
# OPTIONAL: TTP EMPTY-PACK TRAVEL TIME CHECK
# ============================================================
def ttp_time_empty(tour: List[int], dist, data: Dict[str, Any]) -> float:
    """
    TTP travel time with no items picked, using TTP speed function.
    """
    weights = data["items_weight"]
    cities = data["items_city"]
    capacity = data["capacity"]
    v_min = data["v_min"]
    v_max = data["v_max"]

    picked = np.zeros_like(weights, dtype=int)

    current_w = 0.0
    n = len(tour)
    slope = (v_max - v_min) / capacity
    total_time = 0.0

    for i in range(n):
        c = tour[i]
        nxt = tour[(i + 1) % n]

        # no items taken, but we keep structure if you later want to reuse this
        for item_idx in np.where(cities == c)[0]:
            if picked[item_idx] == 1:
                current_w += weights[item_idx]

        speed = v_max - slope * current_w
        if speed < 1e-9:
            return float("inf")

        total_time += dist[c][nxt] / speed

    return total_time


# ============================================================
# MAIN ENTRYPOINT
# ============================================================
def main():
    print(f"[LOAD] Reading instance from: {INSTANCE_PATH}")
    data = parse_ttp(INSTANCE_PATH)
    print(f"[LOAD] Parsed {data['dim']} cities, {len(data['items_profit'])} items.")

    best_tour, best_len, dist = lk_style_tsp_from_ttp(
        data,
        cand_k=CAND_K,
        num_starts=NUM_STARTS,
        ils_restarts=ILS_RESTARTS,
    )

    empty_time = ttp_time_empty(best_tour, dist, data)
    print("\n========== FINAL SUMMARY ==========")
    print(f"TSP best length        : {best_len:.2f}")
    print(f"TTP empty-pack time    : {empty_time:.2f}")
    print("===================================")

    return best_tour, best_len, empty_time


if __name__ == "__main__":
    main()
# Out:
# [LOAD] Reading instance from: C:\MDU\Masters\Nature Inspired\Group Project\Group 5\gecco19-thief\src\main\resources\a280-n279.txt
# [LOAD] Parsed 280 cities, 279 items.
# [INFO] EDGE_WEIGHT_TYPE = CEIL_2D
# [DIST] Building distance matrix...
# [CAND] Building candidate lists (k=3000)...
#
# [START 1/30] constructing initial tour...
# [BASE 1] initial length=3160.00
# [2-OPT S1] start=3160.00
# [2-OPT S1] final=2821.00
# [3-OPT S1] start=2821.00
# [3-OPT S1] final=2821.00 (improved=False)
# [BASIN 1] local min length=2821.00
# [ILS S1] restart 1/200
# [ILS S1] kicked length=3056.00
# [2-OPT S1R1] start=3056.00
# [2-OPT S1R1] final=2850.00
# [3-OPT S1R1] start=2850.00
# [3-OPT S1R1] final=2850.00 (improved=False)
# [ILS S1] no improvement (2850.00 >= 2821.00)
# [ILS S1] restart 2/200
# [ILS S1] kicked length=2890.00
# [2-OPT S1R2] start=2890.00
# [2-OPT S1R2] final=2822.00
# [3-OPT S1R2] start=2822.00
# [3-OPT S1R2] final=2822.00 (improved=False)
# [ILS S1] no improvement (2822.00 >= 2821.00)
# [ILS S1] restart 3/200
# [ILS S1] kicked length=2883.00
# [2-OPT S1R3] start=2883.00
# [2-OPT S1R3] final=2821.00
# [3-OPT S1R3] start=2821.00
# [3-OPT S1R3] final=2821.00 (improved=False)
# [ILS S1] no improvement (2821.00 >= 2821.00)
# [ILS S1] restart 4/200
# [ILS S1] kicked length=3018.00
# [2-OPT S1R4] start=3018.00
# [2-OPT S1R4] final=2821.00
# [3-OPT S1R4] start=2821.00
# [3-OPT S1R4] final=2821.00 (improved=False)
# [ILS S1] no improvement (2821.00 >= 2821.00)
# [ILS S1] restart 5/200
# [ILS S1] kicked length=3114.00
# [2-OPT S1R5] start=3114.00
# [2-OPT S1R5] final=2860.00
# [3-OPT S1R5] start=2860.00
# [3-OPT S1R5] final=2860.00 (improved=False)
# [ILS S1] no improvement (2860.00 >= 2821.00)
# [ILS S1] restart 6/200
# [ILS S1] kicked length=3043.00
# [2-OPT S1R6] start=3043.00
# [2-OPT S1R6] final=2861.00
# [3-OPT S1R6] start=2861.00
# [3-OPT S1R6] final=2861.00 (improved=False)
# [ILS S1] no improvement (2861.00 >= 2821.00)
# [ILS S1] restart 7/200
# [ILS S1] kicked length=3067.00
# [2-OPT S1R7] start=3067.00
# [2-OPT S1R7] final=2843.00
# [3-OPT S1R7] start=2843.00
# [3-OPT S1R7] final=2843.00 (improved=False)
# [ILS S1] no improvement (2843.00 >= 2821.00)
# [ILS S1] restart 8/200
# [ILS S1] kicked length=3149.00
# [2-OPT S1R8] start=3149.00
# [2-OPT S1R8] final=2850.00
# [3-OPT S1R8] start=2850.00
# [3-OPT S1R8] final=2850.00 (improved=False)
# [ILS S1] no improvement (2850.00 >= 2821.00)
# [ILS S1] restart 9/200
# [ILS S1] kicked length=3196.00
# [2-OPT S1R9] start=3196.00
# [2-OPT S1R9] final=2836.00
# [3-OPT S1R9] start=2836.00
# [3-OPT S1R9] final=2836.00 (improved=False)
# [ILS S1] no improvement (2836.00 >= 2821.00)
# [ILS S1] restart 10/200
# [ILS S1] kicked length=3168.00
# [2-OPT S1R10] start=3168.00
# [2-OPT S1R10] final=2833.00
# [3-OPT S1R10] start=2833.00
# [3-OPT S1R10] final=2833.00 (improved=False)
# [ILS S1] no improvement (2833.00 >= 2821.00)
# [ILS S1] restart 11/200
# [ILS S1] kicked length=3193.00
# [2-OPT S1R11] start=3193.00
# [2-OPT S1R11] final=2823.00
# [3-OPT S1R11] start=2823.00
# [3-OPT S1R11] final=2823.00 (improved=False)
# [ILS S1] no improvement (2823.00 >= 2821.00)
# [ILS S1] restart 12/200
# [ILS S1] kicked length=3063.00
# [2-OPT S1R12] start=3063.00
# [2-OPT S1R12] final=2829.00
# [3-OPT S1R12] start=2829.00
# [3-OPT S1R12] final=2829.00 (improved=False)
# [ILS S1] no improvement (2829.00 >= 2821.00)
# [ILS S1] restart 13/200
# [ILS S1] kicked length=2957.00
# [2-OPT S1R13] start=2957.00
# [2-OPT S1R13] final=2845.00
# [3-OPT S1R13] start=2845.00
# [3-OPT S1R13] final=2845.00 (improved=False)
# [ILS S1] no improvement (2845.00 >= 2821.00)
# [ILS S1] restart 14/200
# [ILS S1] kicked length=3035.00
# [2-OPT S1R14] start=3035.00
# [2-OPT S1R14] final=2911.00
# [3-OPT S1R14] start=2911.00
# [3-OPT S1R14] final=2911.00 (improved=False)
# [ILS S1] no improvement (2911.00 >= 2821.00)
# [ILS S1] restart 15/200
# [ILS S1] kicked length=3264.00
# [2-OPT S1R15] start=3264.00
# [2-OPT S1R15] final=2773.00
# [3-OPT S1R15] start=2773.00
# [3-OPT S1R15] final=2773.00 (improved=False)
# [ILS S1] improved basin 2821.00 -> 2773.00
# [ILS S1] restart 16/200
# [ILS S1] kicked length=2962.00
# [2-OPT S1R16] start=2962.00
# [2-OPT S1R16] final=2813.00
# [3-OPT S1R16] start=2813.00
# [3-OPT S1R16] final=2813.00 (improved=False)
# [ILS S1] no improvement (2813.00 >= 2773.00)
# [ILS S1] restart 17/200
# [ILS S1] kicked length=3083.00
# [2-OPT S1R17] start=3083.00
# [2-OPT S1R17] final=2842.00
# [3-OPT S1R17] start=2842.00
# [3-OPT S1R17] final=2842.00 (improved=False)
# [ILS S1] no improvement (2842.00 >= 2773.00)
# [ILS S1] restart 18/200
# [ILS S1] kicked length=3010.00
# [2-OPT S1R18] start=3010.00
# [2-OPT S1R18] final=2759.00
# [3-OPT S1R18] start=2759.00
# [3-OPT S1R18] final=2759.00 (improved=False)
# [ILS S1] improved basin 2773.00 -> 2759.00
# [ILS S1] restart 19/200
# [ILS S1] kicked length=3109.00
# [2-OPT S1R19] start=3109.00
# [2-OPT S1R19] final=2759.00
# [3-OPT S1R19] start=2759.00
# [3-OPT S1R19] final=2759.00 (improved=False)
# [ILS S1] no improvement (2759.00 >= 2759.00)
# [ILS S1] restart 20/200
# [ILS S1] kicked length=3033.00
# [2-OPT S1R20] start=3033.00
# [2-OPT S1R20] final=2804.00
# [3-OPT S1R20] start=2804.00
# [3-OPT S1R20] final=2804.00 (improved=False)
# [ILS S1] no improvement (2804.00 >= 2759.00)
# [ILS S1] restart 21/200
# [ILS S1] kicked length=3070.00
# [2-OPT S1R21] start=3070.00
# [2-OPT S1R21] final=2759.00
# [3-OPT S1R21] start=2759.00
# [3-OPT S1R21] final=2759.00 (improved=False)
# [ILS S1] no improvement (2759.00 >= 2759.00)
# [ILS S1] restart 22/200
# [ILS S1] kicked length=3266.00
# [2-OPT S1R22] start=3266.00
# [2-OPT S1R22] final=2766.00
# [3-OPT S1R22] start=2766.00
# [3-OPT S1R22] final=2766.00 (improved=False)
# [ILS S1] no improvement (2766.00 >= 2759.00)
# [ILS S1] restart 23/200
# [ILS S1] kicked length=3019.00
# [2-OPT S1R23] start=3019.00
# [2-OPT S1R23] final=2830.00
# [3-OPT S1R23] start=2830.00
# [3-OPT S1R23] final=2830.00 (improved=False)
# [ILS S1] no improvement (2830.00 >= 2759.00)
# [ILS S1] restart 24/200
# [ILS S1] kicked length=3074.00
# [2-OPT S1R24] start=3074.00
# [2-OPT S1R24] final=2762.00
# [3-OPT S1R24] start=2762.00
# [3-OPT S1R24] final=2762.00 (improved=False)
# [ILS S1] no improvement (2762.00 >= 2759.00)
# [ILS S1] restart 25/200
# [ILS S1] kicked length=3050.00
# [2-OPT S1R25] start=3050.00
# [2-OPT S1R25] final=2769.00
# [3-OPT S1R25] start=2769.00
# [3-OPT S1R25] final=2769.00 (improved=False)
# [ILS S1] no improvement (2769.00 >= 2759.00)
# [ILS S1] restart 26/200
# [ILS S1] kicked length=3052.00
# [2-OPT S1R26] start=3052.00
# [2-OPT S1R26] final=2769.00
# [3-OPT S1R26] start=2769.00
# [3-OPT S1R26] final=2769.00 (improved=False)
# [ILS S1] no improvement (2769.00 >= 2759.00)
# [ILS S1] restart 27/200
# [ILS S1] kicked length=3034.00
# [2-OPT S1R27] start=3034.00
# [2-OPT S1R27] final=2783.00
# [3-OPT S1R27] start=2783.00
# [3-OPT S1R27] final=2783.00 (improved=False)
# [ILS S1] no improvement (2783.00 >= 2759.00)
# [ILS S1] restart 28/200
# [ILS S1] kicked length=2900.00
# [2-OPT S1R28] start=2900.00
# [2-OPT S1R28] final=2775.00
# [3-OPT S1R28] start=2775.00
# [3-OPT S1R28] final=2775.00 (improved=False)
# [ILS S1] no improvement (2775.00 >= 2759.00)
# [ILS S1] restart 29/200
# [ILS S1] kicked length=3025.00
# [2-OPT S1R29] start=3025.00
# [2-OPT S1R29] final=2759.00
# [3-OPT S1R29] start=2759.00
# [3-OPT S1R29] final=2759.00 (improved=False)
# [ILS S1] no improvement (2759.00 >= 2759.00)
# [ILS S1] restart 30/200
# [ILS S1] kicked length=3045.00
# [2-OPT S1R30] start=3045.00
# [2-OPT S1R30] final=2791.00
# [3-OPT S1R30] start=2791.00
# [3-OPT S1R30] final=2791.00 (improved=False)
# [ILS S1] no improvement (2791.00 >= 2759.00)
# [ILS S1] restart 31/200
# [ILS S1] kicked length=2993.00
# [2-OPT S1R31] start=2993.00
# [2-OPT S1R31] final=2759.00
# [3-OPT S1R31] start=2759.00
# [3-OPT S1R31] final=2759.00 (improved=False)
# [ILS S1] no improvement (2759.00 >= 2759.00)
# [ILS S1] restart 32/200
# [ILS S1] kicked length=3060.00
# [2-OPT S1R32] start=3060.00
# [2-OPT S1R32] final=2759.00
# [3-OPT S1R32] start=2759.00
# [3-OPT S1R32] final=2759.00 (improved=False)
# [ILS S1] no improvement (2759.00 >= 2759.00)
# [ILS S1] restart 33/200
# [ILS S1] kicked length=3065.00
# [2-OPT S1R33] start=3065.00
# [2-OPT S1R33] final=2762.00
# [3-OPT S1R33] start=2762.00
# [3-OPT S1R33] final=2762.00 (improved=False)
# [ILS S1] no improvement (2762.00 >= 2759.00)
# [ILS S1] restart 34/200
# [ILS S1] kicked length=3072.00
# [2-OPT S1R34] start=3072.00
# [2-OPT S1R34] final=2785.00
# [3-OPT S1R34] start=2785.00
# [3-OPT S1R34] final=2785.00 (improved=False)
# [ILS S1] no improvement (2785.00 >= 2759.00)
# [ILS S1] restart 35/200
# [ILS S1] kicked length=3052.00
# [2-OPT S1R35] start=3052.00
# [2-OPT S1R35] final=2764.00
# [3-OPT S1R35] start=2764.00
# [3-OPT S1R35] final=2764.00 (improved=False)
# [ILS S1] no improvement (2764.00 >= 2759.00)
# [ILS S1] restart 36/200
# [ILS S1] kicked length=3088.00
# [2-OPT S1R36] start=3088.00
# [2-OPT S1R36] final=2759.00
# [3-OPT S1R36] start=2759.00
# [3-OPT S1R36] final=2759.00 (improved=False)
# [ILS S1] no improvement (2759.00 >= 2759.00)
# [ILS S1] restart 37/200
# [ILS S1] kicked length=3125.00
# [2-OPT S1R37] start=3125.00
# [2-OPT S1R37] final=2759.00
# [3-OPT S1R37] start=2759.00
# [3-OPT S1R37] final=2759.00 (improved=False)
# [ILS S1] no improvement (2759.00 >= 2759.00)
# [ILS S1] restart 38/200
# [ILS S1] kicked length=2890.00
# [2-OPT S1R38] start=2890.00
# [2-OPT S1R38] final=2841.00
# [3-OPT S1R38] start=2841.00
# [3-OPT S1R38] final=2841.00 (improved=False)
# [ILS S1] no improvement (2841.00 >= 2759.00)
# [ILS S1] restart 39/200
# [ILS S1] kicked length=2965.00
# [2-OPT S1R39] start=2965.00
# [2-OPT S1R39] final=2759.00
# [3-OPT S1R39] start=2759.00
# [3-OPT S1R39] final=2759.00 (improved=False)
# [ILS S1] no improvement (2759.00 >= 2759.00)
# [ILS S1] restart 40/200
# [ILS S1] kicked length=3015.00
# [2-OPT S1R40] start=3015.00
# [2-OPT S1R40] final=2767.00
# [3-OPT S1R40] start=2767.00
# [3-OPT S1R40] final=2767.00 (improved=False)
# [ILS S1] no improvement (2767.00 >= 2759.00)
# [ILS S1] restart 41/200
# [ILS S1] kicked length=3166.00
# [2-OPT S1R41] start=3166.00
# [2-OPT S1R41] final=2800.00
# [3-OPT S1R41] start=2800.00
# [3-OPT S1R41] final=2800.00 (improved=False)
# [ILS S1] no improvement (2800.00 >= 2759.00)
# [ILS S1] restart 42/200
# [ILS S1] kicked length=3158.00
# [2-OPT S1R42] start=3158.00
# [2-OPT S1R42] final=2759.00
# [3-OPT S1R42] start=2759.00
# [3-OPT S1R42] final=2759.00 (improved=False)
# [ILS S1] no improvement (2759.00 >= 2759.00)
# [ILS S1] restart 43/200
# [ILS S1] kicked length=3185.00
# [2-OPT S1R43] start=3185.00
# [2-OPT S1R43] final=2953.00
# [3-OPT S1R43] start=2953.00
# [3-OPT S1R43] final=2953.00 (improved=False)
# [ILS S1] no improvement (2953.00 >= 2759.00)
# [ILS S1] restart 44/200
# [ILS S1] kicked length=2859.00
# [2-OPT S1R44] start=2859.00
# [2-OPT S1R44] final=2759.00
# [3-OPT S1R44] start=2759.00
# [3-OPT S1R44] final=2759.00 (improved=False)
# [ILS S1] no improvement (2759.00 >= 2759.00)
# [ILS S1] restart 45/200
# [ILS S1] kicked length=2960.00
# [2-OPT S1R45] start=2960.00
# [2-OPT S1R45] final=2774.00
# [3-OPT S1R45] start=2774.00
# [3-OPT S1R45] final=2774.00 (improved=False)
# [ILS S1] no improvement (2774.00 >= 2759.00)
# [ILS S1] restart 46/200
# [ILS S1] kicked length=3149.00
# [2-OPT S1R46] start=3149.00
# [2-OPT S1R46] final=2775.00
# [3-OPT S1R46] start=2775.00
# [3-OPT S1R46] final=2775.00 (improved=False)
# [ILS S1] no improvement (2775.00 >= 2759.00)
# [ILS S1] restart 47/200
# [ILS S1] kicked length=3210.00
# [2-OPT S1R47] start=3210.00
# [2-OPT S1R47] final=2767.00
# [3-OPT S1R47] start=2767.00
# [3-OPT S1R47] final=2767.00 (improved=False)
# [ILS S1] no improvement (2767.00 >= 2759.00)
# [ILS S1] restart 48/200
# [ILS S1] kicked length=3049.00
# [2-OPT S1R48] start=3049.00
# [2-OPT S1R48] final=2803.00
# [3-OPT S1R48] start=2803.00
# [3-OPT S1R48] final=2803.00 (improved=False)
# [ILS S1] no improvement (2803.00 >= 2759.00)
# [ILS S1] restart 49/200
# [ILS S1] kicked length=3203.00
# [2-OPT S1R49] start=3203.00
# [2-OPT S1R49] final=2819.00
# [3-OPT S1R49] start=2819.00
# [3-OPT S1R49] final=2819.00 (improved=False)
# [ILS S1] no improvement (2819.00 >= 2759.00)
# [ILS S1] restart 50/200
# [ILS S1] kicked length=3114.00
# [2-OPT S1R50] start=3114.00
# [2-OPT S1R50] final=2768.00
# [3-OPT S1R50] start=2768.00
# [3-OPT S1R50] final=2768.00 (improved=False)
# [ILS S1] no improvement (2768.00 >= 2759.00)
# [ILS S1] restart 51/200
# [ILS S1] kicked length=2980.00
# [2-OPT S1R51] start=2980.00
# [2-OPT S1R51] final=2759.00
# [3-OPT S1R51] start=2759.00
# [3-OPT S1R51] final=2759.00 (improved=False)
# [ILS S1] no improvement (2759.00 >= 2759.00)
# [ILS S1] restart 52/200
# [ILS S1] kicked length=3152.00
# [2-OPT S1R52] start=3152.00
# [2-OPT S1R52] final=2759.00
# [3-OPT S1R52] start=2759.00
# [3-OPT S1R52] final=2759.00 (improved=False)
# [ILS S1] no improvement (2759.00 >= 2759.00)
# [ILS S1] restart 53/200
# [ILS S1] kicked length=3174.00
# [2-OPT S1R53] start=3174.00
# [2-OPT S1R53] final=2759.00
# [3-OPT S1R53] start=2759.00
# [3-OPT S1R53] final=2759.00 (improved=False)
# [ILS S1] no improvement (2759.00 >= 2759.00)
# [ILS S1] restart 54/200
# [ILS S1] kicked length=2959.00
# [2-OPT S1R54] start=2959.00
# [2-OPT S1R54] final=2759.00
# [3-OPT S1R54] start=2759.00
# [3-OPT S1R54] final=2759.00 (improved=False)
# [ILS S1] no improvement (2759.00 >= 2759.00)
# [ILS S1] restart 55/200
# [ILS S1] kicked length=2983.00
# [2-OPT S1R55] start=2983.00
# [2-OPT S1R55] final=2759.00
# [3-OPT S1R55] start=2759.00
# [3-OPT S1R55] final=2759.00 (improved=False)
# [ILS S1] no improvement (2759.00 >= 2759.00)
# [ILS S1] restart 56/200
# [ILS S1] kicked length=3085.00
# [2-OPT S1R56] start=3085.00
# [2-OPT S1R56] final=2796.00
# [3-OPT S1R56] start=2796.00
# [3-OPT S1R56] final=2796.00 (improved=False)
# [ILS S1] no improvement (2796.00 >= 2759.00)
# [ILS S1] restart 57/200
# [ILS S1] kicked length=2821.00
# [2-OPT S1R57] start=2821.00
# [2-OPT S1R57] final=2759.00
# [3-OPT S1R57] start=2759.00
# [3-OPT S1R57] final=2759.00 (improved=False)
# [ILS S1] no improvement (2759.00 >= 2759.00)
# [ILS S1] restart 58/200
# [ILS S1] kicked length=3192.00
# [2-OPT S1R58] start=3192.00
# [2-OPT S1R58] final=2759.00
# [3-OPT S1R58] start=2759.00
# [3-OPT S1R58] final=2759.00 (improved=False)
# [ILS S1] no improvement (2759.00 >= 2759.00)
# [ILS S1] restart 59/200
# [ILS S1] kicked length=3097.00
# [2-OPT S1R59] start=3097.00
# [2-OPT S1R59] final=2720.00
# [3-OPT S1R59] start=2720.00
# [3-OPT S1R59] final=2720.00 (improved=False)
# [ILS S1] improved basin 2759.00 -> 2720.00
# [ILS S1] restart 60/200
# [ILS S1] kicked length=3249.00
# [2-OPT S1R60] start=3249.00
# [2-OPT S1R60] it=50 len=2825.00
# [2-OPT S1R60] final=2784.00
# [3-OPT S1R60] start=2784.00
# [3-OPT S1R60] final=2782.00 (improved=True)
# [ILS S1] no improvement (2782.00 >= 2720.00)
# [ILS S1] restart 61/200
# [ILS S1] kicked length=2921.00
# [2-OPT S1R61] start=2921.00
# [2-OPT S1R61] final=2730.00
# [3-OPT S1R61] start=2730.00
# [3-OPT S1R61] final=2730.00 (improved=False)
# [ILS S1] no improvement (2730.00 >= 2720.00)
# [ILS S1] restart 62/200
# [ILS S1] kicked length=2897.00
# [2-OPT S1R62] start=2897.00
# [2-OPT S1R62] final=2720.00
# [3-OPT S1R62] start=2720.00
# [3-OPT S1R62] final=2720.00 (improved=False)
# [ILS S1] no improvement (2720.00 >= 2720.00)
# [ILS S1] restart 63/200
# [ILS S1] kicked length=2982.00
# [2-OPT S1R63] start=2982.00
# [2-OPT S1R63] final=2777.00
# [3-OPT S1R63] start=2777.00
# [3-OPT S1R63] final=2777.00 (improved=False)
# [ILS S1] no improvement (2777.00 >= 2720.00)
# [ILS S1] restart 64/200
# [ILS S1] kicked length=2912.00
# [2-OPT S1R64] start=2912.00
# [2-OPT S1R64] final=2734.00
# [3-OPT S1R64] start=2734.00
# [3-OPT S1R64] final=2734.00 (improved=False)
# [ILS S1] no improvement (2734.00 >= 2720.00)
# [ILS S1] restart 65/200
# [ILS S1] kicked length=2997.00
# [2-OPT S1R65] start=2997.00
# [2-OPT S1R65] final=2732.00
# [3-OPT S1R65] start=2732.00
# [3-OPT S1R65] final=2732.00 (improved=False)
# [ILS S1] no improvement (2732.00 >= 2720.00)
# [ILS S1] restart 66/200
# [ILS S1] kicked length=3007.00
# [2-OPT S1R66] start=3007.00
# [2-OPT S1R66] final=2720.00
# [3-OPT S1R66] start=2720.00
# [3-OPT S1R66] final=2720.00 (improved=False)
# [ILS S1] no improvement (2720.00 >= 2720.00)
# [ILS S1] restart 67/200
# [ILS S1] kicked length=3032.00
# [2-OPT S1R67] start=3032.00
# [2-OPT S1R67] final=2812.00
# [3-OPT S1R67] start=2812.00
# [3-OPT S1R67] final=2812.00 (improved=False)
# [ILS S1] no improvement (2812.00 >= 2720.00)
# [ILS S1] restart 68/200
# [ILS S1] kicked length=2950.00
# [2-OPT S1R68] start=2950.00
# [2-OPT S1R68] final=2720.00
# [3-OPT S1R68] start=2720.00
# [3-OPT S1R68] final=2720.00 (improved=False)
# [ILS S1] no improvement (2720.00 >= 2720.00)
# [ILS S1] restart 69/200
# [ILS S1] kicked length=3166.00
# [2-OPT S1R69] start=3166.00
# [2-OPT S1R69] it=50 len=2745.00
# [2-OPT S1R69] final=2731.00
# [3-OPT S1R69] start=2731.00
# [3-OPT S1R69] final=2731.00 (improved=False)
# [ILS S1] no improvement (2731.00 >= 2720.00)
# [ILS S1] restart 70/200
# [ILS S1] kicked length=2958.00
# [2-OPT S1R70] start=2958.00
# [2-OPT S1R70] final=2720.00
# [3-OPT S1R70] start=2720.00
# [3-OPT S1R70] final=2720.00 (improved=False)
# [ILS S1] no improvement (2720.00 >= 2720.00)
# [ILS S1] restart 71/200
# [ILS S1] kicked length=3016.00
# [2-OPT S1R71] start=3016.00
# [2-OPT S1R71] final=2720.00
# [3-OPT S1R71] start=2720.00
# [3-OPT S1R71] final=2720.00 (improved=False)
# [ILS S1] no improvement (2720.00 >= 2720.00)
# [ILS S1] restart 72/200
# [ILS S1] kicked length=3111.00
# [2-OPT S1R72] start=3111.00
# [2-OPT S1R72] final=2908.00
# [3-OPT S1R72] start=2908.00
# [3-OPT S1R72] final=2908.00 (improved=False)
# [ILS S1] no improvement (2908.00 >= 2720.00)
# [ILS S1] restart 73/200
# [ILS S1] kicked length=3117.00
# [2-OPT S1R73] start=3117.00
# [2-OPT S1R73] final=2730.00
# [3-OPT S1R73] start=2730.00
# [3-OPT S1R73] final=2730.00 (improved=False)
# [ILS S1] no improvement (2730.00 >= 2720.00)
# [ILS S1] restart 74/200
# [ILS S1] kicked length=2981.00
# [2-OPT S1R74] start=2981.00
# [2-OPT S1R74] final=2726.00
# [3-OPT S1R74] start=2726.00
# [3-OPT S1R74] final=2726.00 (improved=False)
# [ILS S1] no improvement (2726.00 >= 2720.00)
# [ILS S1] restart 75/200
# [ILS S1] kicked length=2818.00
# [2-OPT S1R75] start=2818.00
# [2-OPT S1R75] final=2720.00
# [3-OPT S1R75] start=2720.00
# [3-OPT S1R75] final=2720.00 (improved=False)
# [ILS S1] no improvement (2720.00 >= 2720.00)
# [ILS S1] restart 76/200
# [ILS S1] kicked length=3027.00
# [2-OPT S1R76] start=3027.00
# [2-OPT S1R76] final=2720.00
# [3-OPT S1R76] start=2720.00
# [3-OPT S1R76] final=2720.00 (improved=False)
# [ILS S1] no improvement (2720.00 >= 2720.00)
# [ILS S1] restart 77/200
# [ILS S1] kicked length=3215.00
# [2-OPT S1R77] start=3215.00
# [2-OPT S1R77] final=2720.00
# [3-OPT S1R77] start=2720.00
# [3-OPT S1R77] final=2720.00 (improved=False)
# [ILS S1] no improvement (2720.00 >= 2720.00)
# [ILS S1] restart 78/200
# [ILS S1] kicked length=3145.00
# [2-OPT S1R78] start=3145.00
# [2-OPT S1R78] final=2797.00
# [3-OPT S1R78] start=2797.00
# [3-OPT S1R78] final=2797.00 (improved=False)
# [ILS S1] no improvement (2797.00 >= 2720.00)
# [ILS S1] restart 79/200
# [ILS S1] kicked length=3052.00
# [2-OPT S1R79] start=3052.00
# [2-OPT S1R79] final=2723.00
# [3-OPT S1R79] start=2723.00
# [3-OPT S1R79] final=2723.00 (improved=False)
# [ILS S1] no improvement (2723.00 >= 2720.00)
# [ILS S1] restart 80/200
# [ILS S1] kicked length=3083.00
# [2-OPT S1R80] start=3083.00
# [2-OPT S1R80] final=2723.00
# [3-OPT S1R80] start=2723.00
# [3-OPT S1R80] final=2723.00 (improved=False)
# [ILS S1] no improvement (2723.00 >= 2720.00)
# [ILS S1] restart 81/200
# [ILS S1] kicked length=3118.00
# [2-OPT S1R81] start=3118.00
# [2-OPT S1R81] final=2726.00
# [3-OPT S1R81] start=2726.00
# [3-OPT S1R81] final=2726.00 (improved=False)
# [ILS S1] no improvement (2726.00 >= 2720.00)
# [ILS S1] restart 82/200
# [ILS S1] kicked length=2914.00
# [2-OPT S1R82] start=2914.00
# [2-OPT S1R82] final=2775.00
# [3-OPT S1R82] start=2775.00
# [3-OPT S1R82] final=2775.00 (improved=False)
# [ILS S1] no improvement (2775.00 >= 2720.00)
# [ILS S1] restart 83/200
# [ILS S1] kicked length=2911.00
# [2-OPT S1R83] start=2911.00
# [2-OPT S1R83] final=2724.00
# [3-OPT S1R83] start=2724.00
# [3-OPT S1R83] final=2724.00 (improved=False)
# [ILS S1] no improvement (2724.00 >= 2720.00)
# [ILS S1] restart 84/200
# [ILS S1] kicked length=2953.00
# [2-OPT S1R84] start=2953.00
# [2-OPT S1R84] final=2720.00
# [3-OPT S1R84] start=2720.00
# [3-OPT S1R84] final=2720.00 (improved=False)
# [ILS S1] no improvement (2720.00 >= 2720.00)
# [ILS S1] restart 85/200
# [ILS S1] kicked length=3181.00
# [2-OPT S1R85] start=3181.00
# [2-OPT S1R85] final=2720.00
# [3-OPT S1R85] start=2720.00
# [3-OPT S1R85] final=2720.00 (improved=False)
# [ILS S1] no improvement (2720.00 >= 2720.00)
# [ILS S1] restart 86/200
# [ILS S1] kicked length=2889.00
# [2-OPT S1R86] start=2889.00
# [2-OPT S1R86] final=2725.00
# [3-OPT S1R86] start=2725.00
# [3-OPT S1R86] final=2725.00 (improved=False)
# [ILS S1] no improvement (2725.00 >= 2720.00)
# [ILS S1] restart 87/200
# [ILS S1] kicked length=3035.00
# [2-OPT S1R87] start=3035.00
# [2-OPT S1R87] final=2713.00
# [3-OPT S1R87] start=2713.00
# [3-OPT S1R87] final=2713.00 (improved=False)
# [ILS S1] improved basin 2720.00 -> 2713.00
# [ILS S1] restart 88/200
# [ILS S1] kicked length=3031.00
# [2-OPT S1R88] start=3031.00
# [2-OPT S1R88] final=2767.00
# [3-OPT S1R88] start=2767.00
# [3-OPT S1R88] final=2767.00 (improved=False)
# [ILS S1] no improvement (2767.00 >= 2713.00)
# [ILS S1] restart 89/200
# [ILS S1] kicked length=3044.00
# [2-OPT S1R89] start=3044.00
# [2-OPT S1R89] final=2708.00
# [3-OPT S1R89] start=2708.00
# [3-OPT S1R89] final=2708.00 (improved=False)
# [ILS S1] improved basin 2713.00 -> 2708.00
# [ILS S1] restart 90/200
# [ILS S1] kicked length=2953.00
# [2-OPT S1R90] start=2953.00
# [2-OPT S1R90] final=2708.00
# [3-OPT S1R90] start=2708.00
# [3-OPT S1R90] final=2708.00 (improved=False)
# [ILS S1] no improvement (2708.00 >= 2708.00)
# [ILS S1] restart 91/200
# [ILS S1] kicked length=2978.00
# [2-OPT S1R91] start=2978.00
# [2-OPT S1R91] final=2748.00
# [3-OPT S1R91] start=2748.00
# [3-OPT S1R91] final=2748.00 (improved=False)
# [ILS S1] no improvement (2748.00 >= 2708.00)
# [ILS S1] restart 92/200
# [ILS S1] kicked length=2926.00
# [2-OPT S1R92] start=2926.00
# [2-OPT S1R92] final=2714.00
# [3-OPT S1R92] start=2714.00
# [3-OPT S1R92] final=2714.00 (improved=False)
# [ILS S1] no improvement (2714.00 >= 2708.00)
# [ILS S1] restart 93/200
# [ILS S1] kicked length=2849.00
# [2-OPT S1R93] start=2849.00
# [2-OPT S1R93] final=2708.00
# [3-OPT S1R93] start=2708.00
# [3-OPT S1R93] final=2708.00 (improved=False)
# [ILS S1] no improvement (2708.00 >= 2708.00)
# [ILS S1] restart 94/200
# [ILS S1] kicked length=3045.00
# [2-OPT S1R94] start=3045.00
# [2-OPT S1R94] final=2739.00
# [3-OPT S1R94] start=2739.00
# [3-OPT S1R94] final=2739.00 (improved=False)
# [ILS S1] no improvement (2739.00 >= 2708.00)
# [ILS S1] restart 95/200
# [ILS S1] kicked length=2861.00
# [2-OPT S1R95] start=2861.00
# [2-OPT S1R95] final=2698.00
# [3-OPT S1R95] start=2698.00
# [3-OPT S1R95] final=2698.00 (improved=False)
# [ILS S1] improved basin 2708.00 -> 2698.00
# [ILS S1] restart 96/200
# [ILS S1] kicked length=3070.00
# [2-OPT S1R96] start=3070.00
# [2-OPT S1R96] final=2698.00
# [3-OPT S1R96] start=2698.00
# [3-OPT S1R96] final=2698.00 (improved=False)
# [ILS S1] no improvement (2698.00 >= 2698.00)
# [ILS S1] restart 97/200
# [ILS S1] kicked length=2976.00
# [2-OPT S1R97] start=2976.00
# [2-OPT S1R97] final=2698.00
# [3-OPT S1R97] start=2698.00
# [3-OPT S1R97] final=2698.00 (improved=False)
# [ILS S1] no improvement (2698.00 >= 2698.00)
# [ILS S1] restart 98/200
# [ILS S1] kicked length=3126.00
# [2-OPT S1R98] start=3126.00
# [2-OPT S1R98] final=2699.00
# [3-OPT S1R98] start=2699.00
# [3-OPT S1R98] final=2699.00 (improved=False)
# [ILS S1] no improvement (2699.00 >= 2698.00)
# [ILS S1] restart 99/200
# [ILS S1] kicked length=3023.00
# [2-OPT S1R99] start=3023.00
# [2-OPT S1R99] final=2722.00
# [3-OPT S1R99] start=2722.00
# [3-OPT S1R99] final=2722.00 (improved=False)
# [ILS S1] no improvement (2722.00 >= 2698.00)
# [ILS S1] restart 100/200
# [ILS S1] kicked length=2931.00
# [2-OPT S1R100] start=2931.00
# [2-OPT S1R100] final=2716.00
# [3-OPT S1R100] start=2716.00
# [3-OPT S1R100] final=2716.00 (improved=False)
# [ILS S1] no improvement (2716.00 >= 2698.00)
# [ILS S1] restart 101/200
# [ILS S1] kicked length=3069.00
# [2-OPT S1R101] start=3069.00
# [2-OPT S1R101] final=2701.00
# [3-OPT S1R101] start=2701.00
# [3-OPT S1R101] final=2701.00 (improved=False)
# [ILS S1] no improvement (2701.00 >= 2698.00)
# [ILS S1] restart 102/200
# [ILS S1] kicked length=2848.00
# [2-OPT S1R102] start=2848.00
# [2-OPT S1R102] final=2698.00
# [3-OPT S1R102] start=2698.00
# [3-OPT S1R102] final=2698.00 (improved=False)
# [ILS S1] no improvement (2698.00 >= 2698.00)
# [ILS S1] restart 103/200
# [ILS S1] kicked length=3001.00
# [2-OPT S1R103] start=3001.00
# [2-OPT S1R103] final=2698.00
# [3-OPT S1R103] start=2698.00
# [3-OPT S1R103] final=2698.00 (improved=False)
# [ILS S1] no improvement (2698.00 >= 2698.00)
# [ILS S1] restart 104/200
# [ILS S1] kicked length=3067.00
# [2-OPT S1R104] start=3067.00
# [2-OPT S1R104] final=2785.00
# [3-OPT S1R104] start=2785.00
# [3-OPT S1R104] final=2785.00 (improved=False)
# [ILS S1] no improvement (2785.00 >= 2698.00)
# [ILS S1] restart 105/200
# [ILS S1] kicked length=3178.00
# [2-OPT S1R105] start=3178.00
# [2-OPT S1R105] it=50 len=2779.00
# [2-OPT S1R105] final=2705.00
# [3-OPT S1R105] start=2705.00
# [3-OPT S1R105] final=2705.00 (improved=False)
# [ILS S1] no improvement (2705.00 >= 2698.00)
# [ILS S1] restart 106/200
# [ILS S1] kicked length=3121.00
# [2-OPT S1R106] start=3121.00
# [2-OPT S1R106] final=2698.00
# [3-OPT S1R106] start=2698.00
# [3-OPT S1R106] final=2698.00 (improved=False)
# [ILS S1] no improvement (2698.00 >= 2698.00)
# [ILS S1] restart 107/200
# [ILS S1] kicked length=2906.00
# [2-OPT S1R107] start=2906.00
# [2-OPT S1R107] final=2698.00
# [3-OPT S1R107] start=2698.00
# [3-OPT S1R107] final=2698.00 (improved=False)
# [ILS S1] no improvement (2698.00 >= 2698.00)
# [ILS S1] restart 108/200
# [ILS S1] kicked length=3132.00
# [2-OPT S1R108] start=3132.00
# [2-OPT S1R108] final=2696.00
# [3-OPT S1R108] start=2696.00
# [3-OPT S1R108] final=2696.00 (improved=False)
# [ILS S1] improved basin 2698.00 -> 2696.00
# [ILS S1] restart 109/200
# [ILS S1] kicked length=2996.00
# [2-OPT S1R109] start=2996.00
# [2-OPT S1R109] final=2696.00
# [3-OPT S1R109] start=2696.00
# [3-OPT S1R109] final=2696.00 (improved=False)
# [ILS S1] no improvement (2696.00 >= 2696.00)
# [ILS S1] restart 110/200
# [ILS S1] kicked length=2979.00
# [2-OPT S1R110] start=2979.00
# [2-OPT S1R110] final=2710.00
# [3-OPT S1R110] start=2710.00
# [3-OPT S1R110] final=2710.00 (improved=False)
# [ILS S1] no improvement (2710.00 >= 2696.00)
# [ILS S1] restart 111/200
# [ILS S1] kicked length=3157.00
# [2-OPT S1R111] start=3157.00
# [2-OPT S1R111] final=2760.00
# [3-OPT S1R111] start=2760.00
# [3-OPT S1R111] final=2760.00 (improved=False)
# [ILS S1] no improvement (2760.00 >= 2696.00)
# [ILS S1] restart 112/200
# [ILS S1] kicked length=3154.00
# [2-OPT S1R112] start=3154.00
# [2-OPT S1R112] final=2823.00
# [3-OPT S1R112] start=2823.00
# [3-OPT S1R112] final=2823.00 (improved=False)
# [ILS S1] no improvement (2823.00 >= 2696.00)
# [ILS S1] restart 113/200
# [ILS S1] kicked length=2831.00
# [2-OPT S1R113] start=2831.00
# [2-OPT S1R113] final=2710.00
# [3-OPT S1R113] start=2710.00
# [3-OPT S1R113] final=2710.00 (improved=False)
# [ILS S1] no improvement (2710.00 >= 2696.00)
# [ILS S1] restart 114/200
# [ILS S1] kicked length=2928.00
# [2-OPT S1R114] start=2928.00
# [2-OPT S1R114] final=2837.00
# [3-OPT S1R114] start=2837.00
# [3-OPT S1R114] final=2837.00 (improved=False)
# [ILS S1] no improvement (2837.00 >= 2696.00)
# [ILS S1] restart 115/200
# [ILS S1] kicked length=3019.00
# [2-OPT S1R115] start=3019.00
# [2-OPT S1R115] final=2697.00
# [3-OPT S1R115] start=2697.00
# [3-OPT S1R115] final=2697.00 (improved=False)
# [ILS S1] no improvement (2697.00 >= 2696.00)
# [ILS S1] restart 116/200
# [ILS S1] kicked length=2887.00
# [2-OPT S1R116] start=2887.00
# [2-OPT S1R116] final=2705.00
# [3-OPT S1R116] start=2705.00
# [3-OPT S1R116] final=2705.00 (improved=False)
# [ILS S1] no improvement (2705.00 >= 2696.00)
# [ILS S1] restart 117/200
# [ILS S1] kicked length=3081.00
# [2-OPT S1R117] start=3081.00
# [2-OPT S1R117] final=2708.00
# [3-OPT S1R117] start=2708.00
# [3-OPT S1R117] final=2708.00 (improved=False)
# [ILS S1] no improvement (2708.00 >= 2696.00)
# [ILS S1] restart 118/200
# [ILS S1] kicked length=3279.00
# [2-OPT S1R118] start=3279.00
# [2-OPT S1R118] final=2692.00
# [3-OPT S1R118] start=2692.00
# [3-OPT S1R118] final=2692.00 (improved=False)
# [ILS S1] improved basin 2696.00 -> 2692.00
# [ILS S1] restart 119/200
# [ILS S1] kicked length=3137.00
# [2-OPT S1R119] start=3137.00
# [2-OPT S1R119] final=2692.00
# [3-OPT S1R119] start=2692.00
# [3-OPT S1R119] final=2692.00 (improved=False)
# [ILS S1] no improvement (2692.00 >= 2692.00)
# [ILS S1] restart 120/200
# [ILS S1] kicked length=2985.00
# [2-OPT S1R120] start=2985.00
# [2-OPT S1R120] final=2699.00
# [3-OPT S1R120] start=2699.00
# [3-OPT S1R120] final=2699.00 (improved=False)
# [ILS S1] no improvement (2699.00 >= 2692.00)
# [ILS S1] restart 121/200
# [ILS S1] kicked length=3015.00
# [2-OPT S1R121] start=3015.00
# [2-OPT S1R121] final=2692.00
# [3-OPT S1R121] start=2692.00
# [3-OPT S1R121] final=2692.00 (improved=False)
# [ILS S1] no improvement (2692.00 >= 2692.00)
# [ILS S1] restart 122/200
# [ILS S1] kicked length=3045.00
# [2-OPT S1R122] start=3045.00
# [2-OPT S1R122] final=2852.00
# [3-OPT S1R122] start=2852.00
# [3-OPT S1R122] final=2852.00 (improved=False)
# [ILS S1] no improvement (2852.00 >= 2692.00)
# [ILS S1] restart 123/200
# [ILS S1] kicked length=2891.00
# [2-OPT S1R123] start=2891.00
# [2-OPT S1R123] final=2777.00
# [3-OPT S1R123] start=2777.00
# [3-OPT S1R123] final=2777.00 (improved=False)
# [ILS S1] no improvement (2777.00 >= 2692.00)
# [ILS S1] restart 124/200
# [ILS S1] kicked length=3017.00
# [2-OPT S1R124] start=3017.00
# [2-OPT S1R124] final=2692.00
# [3-OPT S1R124] start=2692.00
# [3-OPT S1R124] final=2692.00 (improved=False)
# [ILS S1] no improvement (2692.00 >= 2692.00)
# [ILS S1] restart 125/200
# [ILS S1] kicked length=3022.00
# [2-OPT S1R125] start=3022.00
# [2-OPT S1R125] final=2705.00
# [3-OPT S1R125] start=2705.00
# [3-OPT S1R125] final=2705.00 (improved=False)
# [ILS S1] no improvement (2705.00 >= 2692.00)
# [ILS S1] restart 126/200
# [ILS S1] kicked length=2998.00
# [2-OPT S1R126] start=2998.00
# [2-OPT S1R126] final=2668.00
# [3-OPT S1R126] start=2668.00
# [3-OPT S1R126] final=2668.00 (improved=False)
# [ILS S1] improved basin 2692.00 -> 2668.00
# [ILS S1] restart 127/200
# [ILS S1] kicked length=3146.00
# [2-OPT S1R127] start=3146.00
# [2-OPT S1R127] final=2718.00
# [3-OPT S1R127] start=2718.00
# [3-OPT S1R127] final=2718.00 (improved=False)
# [ILS S1] no improvement (2718.00 >= 2668.00)
# [ILS S1] restart 128/200
# [ILS S1] kicked length=2945.00
# [2-OPT S1R128] start=2945.00
# [2-OPT S1R128] final=2676.00
# [3-OPT S1R128] start=2676.00
# [3-OPT S1R128] final=2676.00 (improved=False)
# [ILS S1] no improvement (2676.00 >= 2668.00)
# [ILS S1] restart 129/200
# [ILS S1] kicked length=2982.00
# [2-OPT S1R129] start=2982.00
# [2-OPT S1R129] final=2671.00
# [3-OPT S1R129] start=2671.00
# [3-OPT S1R129] final=2671.00 (improved=False)
# [ILS S1] no improvement (2671.00 >= 2668.00)
# [ILS S1] restart 130/200
# [ILS S1] kicked length=2784.00
# [2-OPT S1R130] start=2784.00
# [2-OPT S1R130] final=2668.00
# [3-OPT S1R130] start=2668.00
# [3-OPT S1R130] final=2668.00 (improved=False)
# [ILS S1] no improvement (2668.00 >= 2668.00)
# [ILS S1] restart 131/200
# [ILS S1] kicked length=2875.00
# [2-OPT S1R131] start=2875.00
# [2-OPT S1R131] final=2668.00
# [3-OPT S1R131] start=2668.00
# [3-OPT S1R131] final=2668.00 (improved=False)
# [ILS S1] no improvement (2668.00 >= 2668.00)
# [ILS S1] restart 132/200
# [ILS S1] kicked length=2903.00
# [2-OPT S1R132] start=2903.00
# [2-OPT S1R132] final=2685.00
# [3-OPT S1R132] start=2685.00
# [3-OPT S1R132] final=2685.00 (improved=False)
# [ILS S1] no improvement (2685.00 >= 2668.00)
# [ILS S1] restart 133/200
# [ILS S1] kicked length=3225.00
# [2-OPT S1R133] start=3225.00
# [2-OPT S1R133] final=2682.00
# [3-OPT S1R133] start=2682.00
# [3-OPT S1R133] final=2682.00 (improved=False)
# [ILS S1] no improvement (2682.00 >= 2668.00)
# [ILS S1] restart 134/200
# [ILS S1] kicked length=3083.00
# [2-OPT S1R134] start=3083.00
# [2-OPT S1R134] final=2668.00
# [3-OPT S1R134] start=2668.00
# [3-OPT S1R134] final=2668.00 (improved=False)
# [ILS S1] no improvement (2668.00 >= 2668.00)
# [ILS S1] restart 135/200
# [ILS S1] kicked length=2978.00
# [2-OPT S1R135] start=2978.00
# [2-OPT S1R135] final=2668.00
# [3-OPT S1R135] start=2668.00
# [3-OPT S1R135] final=2668.00 (improved=False)
# [ILS S1] no improvement (2668.00 >= 2668.00)
# [ILS S1] restart 136/200
# [ILS S1] kicked length=3077.00
# [2-OPT S1R136] start=3077.00
# [2-OPT S1R136] final=2668.00
# [3-OPT S1R136] start=2668.00
# [3-OPT S1R136] final=2668.00 (improved=False)
# [ILS S1] no improvement (2668.00 >= 2668.00)
# [ILS S1] restart 137/200
# [ILS S1] kicked length=3004.00
# [2-OPT S1R137] start=3004.00
# [2-OPT S1R137] final=2668.00
# [3-OPT S1R137] start=2668.00
# [3-OPT S1R137] final=2668.00 (improved=False)
# [ILS S1] no improvement (2668.00 >= 2668.00)
# [ILS S1] restart 138/200
# [ILS S1] kicked length=2910.00
# [2-OPT S1R138] start=2910.00
# [2-OPT S1R138] final=2711.00
# [3-OPT S1R138] start=2711.00
# [3-OPT S1R138] final=2711.00 (improved=False)
# [ILS S1] no improvement (2711.00 >= 2668.00)
# [ILS S1] restart 139/200
# [ILS S1] kicked length=2963.00
# [2-OPT S1R139] start=2963.00
# [2-OPT S1R139] final=2668.00
# [3-OPT S1R139] start=2668.00
# [3-OPT S1R139] final=2668.00 (improved=False)
# [ILS S1] no improvement (2668.00 >= 2668.00)
# [ILS S1] restart 140/200
# [ILS S1] kicked length=2893.00
# [2-OPT S1R140] start=2893.00
# [2-OPT S1R140] final=2768.00
# [3-OPT S1R140] start=2768.00
# [3-OPT S1R140] final=2768.00 (improved=False)
# [ILS S1] no improvement (2768.00 >= 2668.00)
# [ILS S1] restart 141/200
# [ILS S1] kicked length=3049.00
# [2-OPT S1R141] start=3049.00
# [2-OPT S1R141] final=2668.00
# [3-OPT S1R141] start=2668.00
# [3-OPT S1R141] final=2668.00 (improved=False)
# [ILS S1] no improvement (2668.00 >= 2668.00)
# [ILS S1] restart 142/200
# [ILS S1] kicked length=2818.00
# [2-OPT S1R142] start=2818.00
# [2-OPT S1R142] final=2668.00
# [3-OPT S1R142] start=2668.00
# [3-OPT S1R142] final=2668.00 (improved=False)
# [ILS S1] no improvement (2668.00 >= 2668.00)
# [ILS S1] restart 143/200
# [ILS S1] kicked length=3034.00
# [2-OPT S1R143] start=3034.00
# [2-OPT S1R143] final=2682.00
# [3-OPT S1R143] start=2682.00
# [3-OPT S1R143] final=2682.00 (improved=False)
# [ILS S1] no improvement (2682.00 >= 2668.00)
# [ILS S1] restart 144/200
# [ILS S1] kicked length=2718.00
# [2-OPT S1R144] start=2718.00
# [2-OPT S1R144] final=2668.00
# [3-OPT S1R144] start=2668.00
# [3-OPT S1R144] final=2668.00 (improved=False)
# [ILS S1] no improvement (2668.00 >= 2668.00)
# [ILS S1] restart 145/200
# [ILS S1] kicked length=2925.00
# [2-OPT S1R145] start=2925.00
# [2-OPT S1R145] final=2682.00
# [3-OPT S1R145] start=2682.00
# [3-OPT S1R145] final=2682.00 (improved=False)
# [ILS S1] no improvement (2682.00 >= 2668.00)
# [ILS S1] restart 146/200
# [ILS S1] kicked length=2960.00
# [2-OPT S1R146] start=2960.00
# [2-OPT S1R146] final=2668.00
# [3-OPT S1R146] start=2668.00
# [3-OPT S1R146] final=2668.00 (improved=False)
# [ILS S1] no improvement (2668.00 >= 2668.00)
# [ILS S1] restart 147/200
# [ILS S1] kicked length=3121.00
# [2-OPT S1R147] start=3121.00
# [2-OPT S1R147] final=2684.00
# [3-OPT S1R147] start=2684.00
# [3-OPT S1R147] final=2684.00 (improved=False)
# [ILS S1] no improvement (2684.00 >= 2668.00)
# [ILS S1] restart 148/200
# [ILS S1] kicked length=2910.00
# [2-OPT S1R148] start=2910.00
# [2-OPT S1R148] final=2668.00
# [3-OPT S1R148] start=2668.00
# [3-OPT S1R148] final=2668.00 (improved=False)
# [ILS S1] no improvement (2668.00 >= 2668.00)
# [ILS S1] restart 149/200
# [ILS S1] kicked length=2978.00
# [2-OPT S1R149] start=2978.00
# [2-OPT S1R149] final=2672.00
# [3-OPT S1R149] start=2672.00
# [3-OPT S1R149] final=2672.00 (improved=False)
# [ILS S1] no improvement (2672.00 >= 2668.00)
# [ILS S1] restart 150/200
# [ILS S1] kicked length=3059.00
# [2-OPT S1R150] start=3059.00
# [2-OPT S1R150] final=2681.00
# [3-OPT S1R150] start=2681.00
# [3-OPT S1R150] final=2681.00 (improved=False)
# [ILS S1] no improvement (2681.00 >= 2668.00)
# [ILS S1] restart 151/200
# [ILS S1] kicked length=2986.00
# [2-OPT S1R151] start=2986.00
# [2-OPT S1R151] final=2672.00
# [3-OPT S1R151] start=2672.00
# [3-OPT S1R151] final=2672.00 (improved=False)
# [ILS S1] no improvement (2672.00 >= 2668.00)
# [ILS S1] restart 152/200
# [ILS S1] kicked length=3167.00
# [2-OPT S1R152] start=3167.00
# [2-OPT S1R152] final=2850.00
# [3-OPT S1R152] start=2850.00
# [3-OPT S1R152] final=2850.00 (improved=False)
# [ILS S1] no improvement (2850.00 >= 2668.00)
# [ILS S1] restart 153/200
# [ILS S1] kicked length=2862.00
# [2-OPT S1R153] start=2862.00
# [2-OPT S1R153] final=2668.00
# [3-OPT S1R153] start=2668.00
# [3-OPT S1R153] final=2668.00 (improved=False)
# [ILS S1] no improvement (2668.00 >= 2668.00)
# [ILS S1] restart 154/200
# [ILS S1] kicked length=2904.00
# [2-OPT S1R154] start=2904.00
# [2-OPT S1R154] final=2675.00
# [3-OPT S1R154] start=2675.00
# [3-OPT S1R154] final=2675.00 (improved=False)
# [ILS S1] no improvement (2675.00 >= 2668.00)
# [ILS S1] restart 155/200
# [ILS S1] kicked length=2904.00
# [2-OPT S1R155] start=2904.00
# [2-OPT S1R155] final=2749.00
# [3-OPT S1R155] start=2749.00
# [3-OPT S1R155] final=2749.00 (improved=False)
# [ILS S1] no improvement (2749.00 >= 2668.00)
# [ILS S1] restart 156/200
# [ILS S1] kicked length=3046.00
# [2-OPT S1R156] start=3046.00
# [2-OPT S1R156] final=2675.00
# [3-OPT S1R156] start=2675.00
# [3-OPT S1R156] final=2675.00 (improved=False)
# [ILS S1] no improvement (2675.00 >= 2668.00)
# [ILS S1] restart 157/200
# [ILS S1] kicked length=3069.00
# [2-OPT S1R157] start=3069.00
# [2-OPT S1R157] final=2668.00
# [3-OPT S1R157] start=2668.00
# [3-OPT S1R157] final=2668.00 (improved=False)
# [ILS S1] no improvement (2668.00 >= 2668.00)
# [ILS S1] restart 158/200
# [ILS S1] kicked length=2883.00
# [2-OPT S1R158] start=2883.00
# [2-OPT S1R158] final=2688.00
# [3-OPT S1R158] start=2688.00
# [3-OPT S1R158] final=2688.00 (improved=False)
# [ILS S1] no improvement (2688.00 >= 2668.00)
# [ILS S1] restart 159/200
# [ILS S1] kicked length=2950.00
# [2-OPT S1R159] start=2950.00
# [2-OPT S1R159] final=2780.00
# [3-OPT S1R159] start=2780.00
# [3-OPT S1R159] final=2780.00 (improved=False)
# [ILS S1] no improvement (2780.00 >= 2668.00)
# [ILS S1] restart 160/200
# [ILS S1] kicked length=2926.00
# [2-OPT S1R160] start=2926.00
# [2-OPT S1R160] final=2678.00
# [3-OPT S1R160] start=2678.00
# [3-OPT S1R160] final=2678.00 (improved=False)
# [ILS S1] no improvement (2678.00 >= 2668.00)
# [ILS S1] restart 161/200
# [ILS S1] kicked length=2877.00
# [2-OPT S1R161] start=2877.00
# [2-OPT S1R161] final=2691.00
# [3-OPT S1R161] start=2691.00
# [3-OPT S1R161] final=2691.00 (improved=False)
# [ILS S1] no improvement (2691.00 >= 2668.00)
# [ILS S1] restart 162/200
# [ILS S1] kicked length=3099.00
# [2-OPT S1R162] start=3099.00
# [2-OPT S1R162] final=2839.00
# [3-OPT S1R162] start=2839.00
# [3-OPT S1R162] final=2839.00 (improved=False)
# [ILS S1] no improvement (2839.00 >= 2668.00)
# [ILS S1] restart 163/200
# [ILS S1] kicked length=2998.00
# [2-OPT S1R163] start=2998.00
# [2-OPT S1R163] final=2709.00
# [3-OPT S1R163] start=2709.00
# [3-OPT S1R163] final=2709.00 (improved=False)
# [ILS S1] no improvement (2709.00 >= 2668.00)
# [ILS S1] restart 164/200
# [ILS S1] kicked length=3052.00
# [2-OPT S1R164] start=3052.00
# [2-OPT S1R164] final=2682.00
# [3-OPT S1R164] start=2682.00
# [3-OPT S1R164] final=2682.00 (improved=False)
# [ILS S1] no improvement (2682.00 >= 2668.00)
# [ILS S1] restart 165/200
# [ILS S1] kicked length=2985.00
# [2-OPT S1R165] start=2985.00
# [2-OPT S1R165] final=2759.00
# [3-OPT S1R165] start=2759.00
# [3-OPT S1R165] final=2759.00 (improved=False)
# [ILS S1] no improvement (2759.00 >= 2668.00)
# [ILS S1] restart 166/200
# [ILS S1] kicked length=3052.00
# [2-OPT S1R166] start=3052.00
# [2-OPT S1R166] final=2789.00
# [3-OPT S1R166] start=2789.00
# [3-OPT S1R166] final=2789.00 (improved=False)
# [ILS S1] no improvement (2789.00 >= 2668.00)
# [ILS S1] restart 167/200
# [ILS S1] kicked length=2949.00
# [2-OPT S1R167] start=2949.00
# [2-OPT S1R167] final=2668.00
# [3-OPT S1R167] start=2668.00
# [3-OPT S1R167] final=2668.00 (improved=False)
# [ILS S1] no improvement (2668.00 >= 2668.00)
# [ILS S1] restart 168/200
# [ILS S1] kicked length=2871.00
# [2-OPT S1R168] start=2871.00
# [2-OPT S1R168] final=2668.00
# [3-OPT S1R168] start=2668.00
# [3-OPT S1R168] final=2668.00 (improved=False)
# [ILS S1] no improvement (2668.00 >= 2668.00)
# [ILS S1] restart 169/200
# [ILS S1] kicked length=3046.00
# [2-OPT S1R169] start=3046.00
# [2-OPT S1R169] final=2675.00
# [3-OPT S1R169] start=2675.00
# [3-OPT S1R169] final=2675.00 (improved=False)
# [ILS S1] no improvement (2675.00 >= 2668.00)
# [ILS S1] restart 170/200
# [ILS S1] kicked length=3154.00
# [2-OPT S1R170] start=3154.00
# [2-OPT S1R170] final=2682.00
# [3-OPT S1R170] start=2682.00
# [3-OPT S1R170] final=2682.00 (improved=False)
# [ILS S1] no improvement (2682.00 >= 2668.00)
# [ILS S1] restart 171/200
# [ILS S1] kicked length=3011.00
# [2-OPT S1R171] start=3011.00
# [2-OPT S1R171] final=2735.00
# [3-OPT S1R171] start=2735.00
# [3-OPT S1R171] final=2735.00 (improved=False)
# [ILS S1] no improvement (2735.00 >= 2668.00)
# [ILS S1] restart 172/200
# [ILS S1] kicked length=2984.00
# [2-OPT S1R172] start=2984.00
# [2-OPT S1R172] final=2668.00
# [3-OPT S1R172] start=2668.00
# [3-OPT S1R172] final=2668.00 (improved=False)
# [ILS S1] no improvement (2668.00 >= 2668.00)
# [ILS S1] restart 173/200
# [ILS S1] kicked length=3174.00
# [2-OPT S1R173] start=3174.00
# [2-OPT S1R173] final=2674.00
# [3-OPT S1R173] start=2674.00
# [3-OPT S1R173] final=2674.00 (improved=False)
# [ILS S1] no improvement (2674.00 >= 2668.00)
# [ILS S1] restart 174/200
# [ILS S1] kicked length=3013.00
# [2-OPT S1R174] start=3013.00
# [2-OPT S1R174] final=2682.00
# [3-OPT S1R174] start=2682.00
# [3-OPT S1R174] final=2671.00 (improved=True)
# [ILS S1] no improvement (2671.00 >= 2668.00)
# [ILS S1] restart 175/200
# [ILS S1] kicked length=3037.00
# [2-OPT S1R175] start=3037.00
# [2-OPT S1R175] final=2777.00
# [3-OPT S1R175] start=2777.00
# [3-OPT S1R175] final=2777.00 (improved=False)
# [ILS S1] no improvement (2777.00 >= 2668.00)
# [ILS S1] restart 176/200
# [ILS S1] kicked length=2972.00
# [2-OPT S1R176] start=2972.00
# [2-OPT S1R176] final=2672.00
# [3-OPT S1R176] start=2672.00
# [3-OPT S1R176] final=2672.00 (improved=False)
# [ILS S1] no improvement (2672.00 >= 2668.00)
# [ILS S1] restart 177/200
# [ILS S1] kicked length=2884.00
# [2-OPT S1R177] start=2884.00
# [2-OPT S1R177] final=2676.00
# [3-OPT S1R177] start=2676.00
# [3-OPT S1R177] final=2676.00 (improved=False)
# [ILS S1] no improvement (2676.00 >= 2668.00)
# [ILS S1] restart 178/200
# [ILS S1] kicked length=3151.00
# [2-OPT S1R178] start=3151.00
# [2-OPT S1R178] final=2688.00
# [3-OPT S1R178] start=2688.00
# [3-OPT S1R178] final=2688.00 (improved=False)
# [ILS S1] no improvement (2688.00 >= 2668.00)
# [ILS S1] restart 179/200
# [ILS S1] kicked length=3166.00
# [2-OPT S1R179] start=3166.00
# [2-OPT S1R179] final=2682.00
# [3-OPT S1R179] start=2682.00
# [3-OPT S1R179] final=2682.00 (improved=False)
# [ILS S1] no improvement (2682.00 >= 2668.00)
# [ILS S1] restart 180/200
# [ILS S1] kicked length=3024.00
# [2-OPT S1R180] start=3024.00
# [2-OPT S1R180] final=2702.00
# [3-OPT S1R180] start=2702.00
# [3-OPT S1R180] final=2702.00 (improved=False)
# [ILS S1] no improvement (2702.00 >= 2668.00)
# [ILS S1] restart 181/200
# [ILS S1] kicked length=2910.00
# [2-OPT S1R181] start=2910.00
# [2-OPT S1R181] final=2668.00
# [3-OPT S1R181] start=2668.00
# [3-OPT S1R181] final=2668.00 (improved=False)
# [ILS S1] no improvement (2668.00 >= 2668.00)
# [ILS S1] restart 182/200
# [ILS S1] kicked length=2914.00
# [2-OPT S1R182] start=2914.00
# [2-OPT S1R182] final=2682.00
# [3-OPT S1R182] start=2682.00
# [3-OPT S1R182] final=2682.00 (improved=False)
# [ILS S1] no improvement (2682.00 >= 2668.00)
# [ILS S1] restart 183/200
# [ILS S1] kicked length=3081.00
# [2-OPT S1R183] start=3081.00
# [2-OPT S1R183] final=2685.00
# [3-OPT S1R183] start=2685.00
# [3-OPT S1R183] final=2685.00 (improved=False)
# [ILS S1] no improvement (2685.00 >= 2668.00)
# [ILS S1] restart 184/200
# [ILS S1] kicked length=3002.00
# [2-OPT S1R184] start=3002.00
# [2-OPT S1R184] final=2668.00
# [3-OPT S1R184] start=2668.00
# [3-OPT S1R184] final=2668.00 (improved=False)
# [ILS S1] no improvement (2668.00 >= 2668.00)
# [ILS S1] restart 185/200
# [ILS S1] kicked length=3087.00
# [2-OPT S1R185] start=3087.00
# [2-OPT S1R185] final=2691.00
# [3-OPT S1R185] start=2691.00
# [3-OPT S1R185] final=2691.00 (improved=False)
# [ILS S1] no improvement (2691.00 >= 2668.00)
# [ILS S1] restart 186/200
# [ILS S1] kicked length=2830.00
# [2-OPT S1R186] start=2830.00
# [2-OPT S1R186] final=2668.00
# [3-OPT S1R186] start=2668.00
# [3-OPT S1R186] final=2668.00 (improved=False)
# [ILS S1] no improvement (2668.00 >= 2668.00)
# [ILS S1] restart 187/200
# [ILS S1] kicked length=2970.00
# [2-OPT S1R187] start=2970.00
# [2-OPT S1R187] final=2668.00
# [3-OPT S1R187] start=2668.00
# [3-OPT S1R187] final=2668.00 (improved=False)
# [ILS S1] no improvement (2668.00 >= 2668.00)
# [ILS S1] restart 188/200
# [ILS S1] kicked length=3081.00
# [2-OPT S1R188] start=3081.00
# [2-OPT S1R188] final=2693.00
# [3-OPT S1R188] start=2693.00
# [3-OPT S1R188] final=2693.00 (improved=False)
# [ILS S1] no improvement (2693.00 >= 2668.00)
# [ILS S1] restart 189/200
# [ILS S1] kicked length=2973.00
# [2-OPT S1R189] start=2973.00
# [2-OPT S1R189] final=2668.00
# [3-OPT S1R189] start=2668.00
# [3-OPT S1R189] final=2668.00 (improved=False)
# [ILS S1] no improvement (2668.00 >= 2668.00)
# [ILS S1] restart 190/200
# [ILS S1] kicked length=2993.00
# [2-OPT S1R190] start=2993.00
# [2-OPT S1R190] final=2653.00
# [3-OPT S1R190] start=2653.00
# [3-OPT S1R190] final=2653.00 (improved=False)
# [ILS S1] improved basin 2668.00 -> 2653.00
# [ILS S1] restart 191/200
# [ILS S1] kicked length=2917.00
# [2-OPT S1R191] start=2917.00
# [2-OPT S1R191] final=2653.00
# [3-OPT S1R191] start=2653.00
# [3-OPT S1R191] final=2653.00 (improved=False)
# [ILS S1] no improvement (2653.00 >= 2653.00)
# [ILS S1] restart 192/200
# [ILS S1] kicked length=2734.00
# [2-OPT S1R192] start=2734.00
# [2-OPT S1R192] final=2668.00
# [3-OPT S1R192] start=2668.00
# [3-OPT S1R192] final=2668.00 (improved=False)
# [ILS S1] no improvement (2668.00 >= 2653.00)
# [ILS S1] restart 193/200
# [ILS S1] kicked length=3091.00
# [2-OPT S1R193] start=3091.00
# [2-OPT S1R193] final=2653.00
# [3-OPT S1R193] start=2653.00
# [3-OPT S1R193] final=2653.00 (improved=False)
# [ILS S1] no improvement (2653.00 >= 2653.00)
# [ILS S1] restart 194/200
# [ILS S1] kicked length=3182.00
# [2-OPT S1R194] start=3182.00
# [2-OPT S1R194] it=50 len=2672.00
# [2-OPT S1R194] final=2672.00
# [3-OPT S1R194] start=2672.00
# [3-OPT S1R194] final=2672.00 (improved=False)
# [ILS S1] no improvement (2672.00 >= 2653.00)
# [ILS S1] restart 195/200
# [ILS S1] kicked length=2919.00
# [2-OPT S1R195] start=2919.00
# [2-OPT S1R195] final=2762.00
# [3-OPT S1R195] start=2762.00
# [3-OPT S1R195] final=2762.00 (improved=False)
# [ILS S1] no improvement (2762.00 >= 2653.00)
# [ILS S1] restart 196/200
# [ILS S1] kicked length=3017.00
# [2-OPT S1R196] start=3017.00
# [2-OPT S1R196] final=2661.00
# [3-OPT S1R196] start=2661.00
# [3-OPT S1R196] final=2661.00 (improved=False)
# [ILS S1] no improvement (2661.00 >= 2653.00)
# [ILS S1] restart 197/200
# [ILS S1] kicked length=2881.00
# [2-OPT S1R197] start=2881.00
# [2-OPT S1R197] final=2653.00
# [3-OPT S1R197] start=2653.00
# [3-OPT S1R197] final=2653.00 (improved=False)
# [ILS S1] no improvement (2653.00 >= 2653.00)
# [ILS S1] restart 198/200
# [ILS S1] kicked length=3020.00
# [2-OPT S1R198] start=3020.00
# [2-OPT S1R198] final=2675.00
# [3-OPT S1R198] start=2675.00
# [3-OPT S1R198] final=2675.00 (improved=False)
# [ILS S1] no improvement (2675.00 >= 2653.00)
# [ILS S1] restart 199/200
# [ILS S1] kicked length=3060.00
# [2-OPT S1R199] start=3060.00
# [2-OPT S1R199] final=2657.00
# [3-OPT S1R199] start=2657.00
# [3-OPT S1R199] final=2657.00 (improved=False)
# [ILS S1] no improvement (2657.00 >= 2653.00)
# [ILS S1] restart 200/200
# [ILS S1] kicked length=3147.00
# [2-OPT S1R200] start=3147.00
# [2-OPT S1R200] final=2833.00
# [3-OPT S1R200] start=2833.00
# [3-OPT S1R200] final=2833.00 (improved=False)
# [ILS S1] no improvement (2833.00 >= 2653.00)
# [GLOBAL] improved inf -> 2653.00
#
# [START 2/30] constructing initial tour...
# [BASE 2] initial length=15017.00
# [2-OPT S2] start=15017.00
# [2-OPT S2] it=50 len=14133.00
# [2-OPT S2] it=100 len=13612.00
# [2-OPT S2] it=150 len=12700.00
# [2-OPT S2] it=200 len=11982.00
# [2-OPT S2] it=250 len=11399.00
# [2-OPT S2] it=300 len=10672.00
# [2-OPT S2] it=350 len=9718.00
# [2-OPT S2] it=400 len=8955.00
# [2-OPT S2] it=450 len=8162.00
# [2-OPT S2] it=500 len=7077.00
# [2-OPT S2] it=550 len=5754.00
# [2-OPT S2] it=600 len=4951.00
# [2-OPT S2] it=650 len=3840.00
# [2-OPT S2] it=700 len=3377.00
# [2-OPT S2] final=3040.00
# [3-OPT S2] start=3040.00
# [3-OPT S2] final=2986.00 (improved=True)
# [BASIN 2] local min length=2986.00
# [ILS S2] restart 1/200
# [ILS S2] kicked length=3371.00
# [2-OPT S2R1] start=3371.00
# [2-OPT S2R1] final=2943.00
# [3-OPT S2R1] start=2943.00
# [3-OPT S2R1] final=2933.00 (improved=True)
# [ILS S2] improved basin 2986.00 -> 2933.00
# [ILS S2] restart 2/200
# [ILS S2] kicked length=3159.00
# [2-OPT S2R2] start=3159.00
# [2-OPT S2R2] final=2939.00
# [3-OPT S2R2] start=2939.00
# [3-OPT S2R2] final=2936.00 (improved=True)
# ...
# [ILS S30] restart 136/200
# [ILS S30] kicked length=2985.00
# [2-OPT S30R136] start=2985.00
# [2-OPT S30R136] final=2772.00
# [3-OPT S30R136] start=2772.00
# [3-OPT S30R136] final=2772.00 (improved=False)
# [ILS S30] no improvement (2772.00 >= 2706.00)
# [ILS S30] restart 137/200
# [ILS S30] kicked length=3096.00
# [2-OPT S30R137] start=3096.00
# [2-OPT S30R137] final=2781.00
# [3-OPT S30R137] start=2781.00
# [3-OPT S30R137] final=2781.00 (improved=False)
# [ILS S30] no improvement (2781.00 >= 2706.00)
# [ILS S30] restart 138/200
# [ILS S30] kicked length=3006.00
# [2-OPT S30R138] start=3006.00
# [2-OPT S30R138] final=2706.00
# [3-OPT S30R138] start=2706.00
# [3-OPT S30R138] final=2706.00 (improved=False)
# [ILS S30] no improvement (2706.00 >= 2706.00)
# [ILS S30] restart 139/200
# [ILS S30] kicked length=3178.00
# [2-OPT S30R139] start=3178.00
# [2-OPT S30R139] final=2916.00
# [3-OPT S30R139] start=2916.00
# [3-OPT S30R139] final=2916.00 (improved=False)
# [ILS S30] no improvement (2916.00 >= 2706.00)
# [ILS S30] restart 140/200
# [ILS S30] kicked length=2983.00
# [2-OPT S30R140] start=2983.00
# [2-OPT S30R140] final=2784.00
# [3-OPT S30R140] start=2784.00
# [3-OPT S30R140] final=2784.00 (improved=False)
# [ILS S30] no improvement (2784.00 >= 2706.00)
# [ILS S30] restart 141/200
# [ILS S30] kicked length=2968.00
# [2-OPT S30R141] start=2968.00
# [2-OPT S30R141] final=2832.00
# [3-OPT S30R141] start=2832.00
# [3-OPT S30R141] final=2832.00 (improved=False)
# [ILS S30] no improvement (2832.00 >= 2706.00)
# [ILS S30] restart 142/200
# [ILS S30] kicked length=2870.00
# [2-OPT S30R142] start=2870.00
# [2-OPT S30R142] final=2733.00
# [3-OPT S30R142] start=2733.00
# [3-OPT S30R142] final=2733.00 (improved=False)
# [ILS S30] no improvement (2733.00 >= 2706.00)
# [ILS S30] restart 143/200
# [ILS S30] kicked length=2959.00
# [2-OPT S30R143] start=2959.00
# [2-OPT S30R143] final=2706.00
# [3-OPT S30R143] start=2706.00
# [3-OPT S30R143] final=2706.00 (improved=False)
# [ILS S30] no improvement (2706.00 >= 2706.00)
# [ILS S30] restart 144/200
# [ILS S30] kicked length=3207.00
# [2-OPT S30R144] start=3207.00
# [2-OPT S30R144] final=2722.00
# [3-OPT S30R144] start=2722.00
# [3-OPT S30R144] final=2722.00 (improved=False)
# [ILS S30] no improvement (2722.00 >= 2706.00)
# [ILS S30] restart 145/200
# [ILS S30] kicked length=2968.00
# [2-OPT S30R145] start=2968.00
# [2-OPT S30R145] final=2706.00
# [3-OPT S30R145] start=2706.00
# [3-OPT S30R145] final=2706.00 (improved=False)
# [ILS S30] no improvement (2706.00 >= 2706.00)
# [ILS S30] restart 146/200
# [ILS S30] kicked length=2923.00
# [2-OPT S30R146] start=2923.00
# [2-OPT S30R146] final=2714.00
# [3-OPT S30R146] start=2714.00
# [3-OPT S30R146] final=2714.00 (improved=False)
# [ILS S30] no improvement (2714.00 >= 2706.00)
# [ILS S30] restart 147/200
# [ILS S30] kicked length=2742.00
# [2-OPT S30R147] start=2742.00
# [2-OPT S30R147] final=2705.00
# [3-OPT S30R147] start=2705.00
# [3-OPT S30R147] final=2705.00 (improved=False)
# [ILS S30] improved basin 2706.00 -> 2705.00
# [ILS S30] restart 148/200
# [ILS S30] kicked length=2957.00
# [2-OPT S30R148] start=2957.00
# [2-OPT S30R148] final=2790.00
# [3-OPT S30R148] start=2790.00
# [3-OPT S30R148] final=2790.00 (improved=False)
# [ILS S30] no improvement (2790.00 >= 2705.00)
# [ILS S30] restart 149/200
# [ILS S30] kicked length=3103.00
# [2-OPT S30R149] start=3103.00
# [2-OPT S30R149] final=2854.00
# [3-OPT S30R149] start=2854.00
# [3-OPT S30R149] final=2854.00 (improved=False)
# [ILS S30] no improvement (2854.00 >= 2705.00)
# [ILS S30] restart 150/200
# [ILS S30] kicked length=3189.00
# [2-OPT S30R150] start=3189.00
# [2-OPT S30R150] final=2756.00
# [3-OPT S30R150] start=2756.00
# [3-OPT S30R150] final=2756.00 (improved=False)
# [ILS S30] no improvement (2756.00 >= 2705.00)
# [ILS S30] restart 151/200
# [ILS S30] kicked length=2942.00
# [2-OPT S30R151] start=2942.00
# [2-OPT S30R151] final=2706.00
# [3-OPT S30R151] start=2706.00
# [3-OPT S30R151] final=2706.00 (improved=False)
# [ILS S30] no improvement (2706.00 >= 2705.00)
# [ILS S30] restart 152/200
# [ILS S30] kicked length=2850.00
# [2-OPT S30R152] start=2850.00
# [2-OPT S30R152] final=2716.00
# [3-OPT S30R152] start=2716.00
# [3-OPT S30R152] final=2716.00 (improved=False)
# [ILS S30] no improvement (2716.00 >= 2705.00)
# [ILS S30] restart 153/200
# [ILS S30] kicked length=3054.00
# [2-OPT S30R153] start=3054.00
# [2-OPT S30R153] final=2722.00
# [3-OPT S30R153] start=2722.00
# [3-OPT S30R153] final=2718.00 (improved=True)
# [ILS S30] no improvement (2718.00 >= 2705.00)
# [ILS S30] restart 154/200
# [ILS S30] kicked length=3167.00
# [2-OPT S30R154] start=3167.00
# [2-OPT S30R154] final=2705.00
# [3-OPT S30R154] start=2705.00
# [3-OPT S30R154] final=2705.00 (improved=False)
# [ILS S30] no improvement (2705.00 >= 2705.00)
# [ILS S30] restart 155/200
# [ILS S30] kicked length=2947.00
# [2-OPT S30R155] start=2947.00
# [2-OPT S30R155] final=2782.00
# [3-OPT S30R155] start=2782.00
# [3-OPT S30R155] final=2782.00 (improved=False)
# [ILS S30] no improvement (2782.00 >= 2705.00)
# [ILS S30] restart 156/200
# [ILS S30] kicked length=3017.00
# [2-OPT S30R156] start=3017.00
# [2-OPT S30R156] final=2722.00
# [3-OPT S30R156] start=2722.00
# [3-OPT S30R156] final=2722.00 (improved=False)
# [ILS S30] no improvement (2722.00 >= 2705.00)
# [ILS S30] restart 157/200
# [ILS S30] kicked length=2965.00
# [2-OPT S30R157] start=2965.00
# [2-OPT S30R157] final=2705.00
# [3-OPT S30R157] start=2705.00
# [3-OPT S30R157] final=2705.00 (improved=False)
# [ILS S30] no improvement (2705.00 >= 2705.00)
# [ILS S30] restart 158/200
# [ILS S30] kicked length=2995.00
# [2-OPT S30R158] start=2995.00
# [2-OPT S30R158] final=2705.00
# [3-OPT S30R158] start=2705.00
# [3-OPT S30R158] final=2705.00 (improved=False)
# [ILS S30] no improvement (2705.00 >= 2705.00)
# [ILS S30] restart 159/200
# [ILS S30] kicked length=3082.00
# [2-OPT S30R159] start=3082.00
# [2-OPT S30R159] final=2737.00
# [3-OPT S30R159] start=2737.00
# [3-OPT S30R159] final=2737.00 (improved=False)
# [ILS S30] no improvement (2737.00 >= 2705.00)
# [ILS S30] restart 160/200
# [ILS S30] kicked length=2935.00
# [2-OPT S30R160] start=2935.00
# [2-OPT S30R160] final=2725.00
# [3-OPT S30R160] start=2725.00
# [3-OPT S30R160] final=2725.00 (improved=False)
# [ILS S30] no improvement (2725.00 >= 2705.00)
# [ILS S30] restart 161/200
# [ILS S30] kicked length=3150.00
# [2-OPT S30R161] start=3150.00
# [2-OPT S30R161] final=2891.00
# [3-OPT S30R161] start=2891.00
# [3-OPT S30R161] final=2891.00 (improved=False)
# [ILS S30] no improvement (2891.00 >= 2705.00)
# [ILS S30] restart 162/200
# [ILS S30] kicked length=3124.00
# [2-OPT S30R162] start=3124.00
# [2-OPT S30R162] final=2755.00
# [3-OPT S30R162] start=2755.00
# [3-OPT S30R162] final=2755.00 (improved=False)
# [ILS S30] no improvement (2755.00 >= 2705.00)
# [ILS S30] restart 163/200
# [ILS S30] kicked length=3222.00
# [2-OPT S30R163] start=3222.00
# [2-OPT S30R163] final=2725.00
# [3-OPT S30R163] start=2725.00
# [3-OPT S30R163] final=2725.00 (improved=False)
# [ILS S30] no improvement (2725.00 >= 2705.00)
# [ILS S30] restart 164/200
# [ILS S30] kicked length=3006.00
# [2-OPT S30R164] start=3006.00
# [2-OPT S30R164] final=2715.00
# [3-OPT S30R164] start=2715.00
# [3-OPT S30R164] final=2715.00 (improved=False)
# [ILS S30] no improvement (2715.00 >= 2705.00)
# [ILS S30] restart 165/200
# [ILS S30] kicked length=2964.00
# [2-OPT S30R165] start=2964.00
# [2-OPT S30R165] final=2808.00
# [3-OPT S30R165] start=2808.00
# [3-OPT S30R165] final=2808.00 (improved=False)
# [ILS S30] no improvement (2808.00 >= 2705.00)
# [ILS S30] restart 166/200
# [ILS S30] kicked length=3175.00
# [2-OPT S30R166] start=3175.00
# [2-OPT S30R166] final=2705.00
# [3-OPT S30R166] start=2705.00
# [3-OPT S30R166] final=2705.00 (improved=False)
# [ILS S30] no improvement (2705.00 >= 2705.00)
# [ILS S30] restart 167/200
# [ILS S30] kicked length=3008.00
# [2-OPT S30R167] start=3008.00
# [2-OPT S30R167] final=2714.00
# [3-OPT S30R167] start=2714.00
# [3-OPT S30R167] final=2714.00 (improved=False)
# [ILS S30] no improvement (2714.00 >= 2705.00)
# [ILS S30] restart 168/200
# [ILS S30] kicked length=3059.00
# [2-OPT S30R168] start=3059.00
# [2-OPT S30R168] final=2752.00
# [3-OPT S30R168] start=2752.00
# [3-OPT S30R168] final=2738.00 (improved=True)
# [ILS S30] no improvement (2738.00 >= 2705.00)
# [ILS S30] restart 169/200
# [ILS S30] kicked length=2840.00
# [2-OPT S30R169] start=2840.00
# [2-OPT S30R169] final=2705.00
# [3-OPT S30R169] start=2705.00
# [3-OPT S30R169] final=2705.00 (improved=False)
# [ILS S30] no improvement (2705.00 >= 2705.00)
# [ILS S30] restart 170/200
# [ILS S30] kicked length=3093.00
# [2-OPT S30R170] start=3093.00
# [2-OPT S30R170] final=2816.00
# [3-OPT S30R170] start=2816.00
# [3-OPT S30R170] final=2816.00 (improved=False)
# [ILS S30] no improvement (2816.00 >= 2705.00)
# [ILS S30] restart 171/200
# [ILS S30] kicked length=2909.00
# [2-OPT S30R171] start=2909.00
# [2-OPT S30R171] final=2710.00
# [3-OPT S30R171] start=2710.00
# [3-OPT S30R171] final=2710.00 (improved=False)
# [ILS S30] no improvement (2710.00 >= 2705.00)
# [ILS S30] restart 172/200
# [ILS S30] kicked length=3017.00
# [2-OPT S30R172] start=3017.00
# [2-OPT S30R172] final=2735.00
# [3-OPT S30R172] start=2735.00
# [3-OPT S30R172] final=2735.00 (improved=False)
# [ILS S30] no improvement (2735.00 >= 2705.00)
# [ILS S30] restart 173/200
# [ILS S30] kicked length=2998.00
# [2-OPT S30R173] start=2998.00
# [2-OPT S30R173] final=2729.00
# [3-OPT S30R173] start=2729.00
# [3-OPT S30R173] final=2729.00 (improved=False)
# [ILS S30] no improvement (2729.00 >= 2705.00)
# [ILS S30] restart 174/200
# [ILS S30] kicked length=2961.00
# [2-OPT S30R174] start=2961.00
# [2-OPT S30R174] final=2705.00
# [3-OPT S30R174] start=2705.00
# [3-OPT S30R174] final=2705.00 (improved=False)
# [ILS S30] no improvement (2705.00 >= 2705.00)
# [ILS S30] restart 175/200
# [ILS S30] kicked length=2884.00
# [2-OPT S30R175] start=2884.00
# [2-OPT S30R175] final=2705.00
# [3-OPT S30R175] start=2705.00
# [3-OPT S30R175] final=2705.00 (improved=False)
# [ILS S30] no improvement (2705.00 >= 2705.00)
# [ILS S30] restart 176/200
# [ILS S30] kicked length=2917.00
# [2-OPT S30R176] start=2917.00
# [2-OPT S30R176] final=2782.00
# [3-OPT S30R176] start=2782.00
# [3-OPT S30R176] final=2782.00 (improved=False)
# [ILS S30] no improvement (2782.00 >= 2705.00)
# [ILS S30] restart 177/200
# [ILS S30] kicked length=3268.00
# [2-OPT S30R177] start=3268.00
# [2-OPT S30R177] it=50 len=2859.00
# [2-OPT S30R177] final=2771.00
# [3-OPT S30R177] start=2771.00
# [3-OPT S30R177] final=2771.00 (improved=False)
# [ILS S30] no improvement (2771.00 >= 2705.00)
# [ILS S30] restart 178/200
# [ILS S30] kicked length=2891.00
# [2-OPT S30R178] start=2891.00
# [2-OPT S30R178] final=2705.00
# [3-OPT S30R178] start=2705.00
# [3-OPT S30R178] final=2705.00 (improved=False)
# [ILS S30] no improvement (2705.00 >= 2705.00)
# [ILS S30] restart 179/200
# [ILS S30] kicked length=3052.00
# [2-OPT S30R179] start=3052.00
# [2-OPT S30R179] final=2824.00
# [3-OPT S30R179] start=2824.00
# [3-OPT S30R179] final=2824.00 (improved=False)
# [ILS S30] no improvement (2824.00 >= 2705.00)
# [ILS S30] restart 180/200
# [ILS S30] kicked length=3104.00
# [2-OPT S30R180] start=3104.00
# [2-OPT S30R180] final=2721.00
# [3-OPT S30R180] start=2721.00
# [3-OPT S30R180] final=2721.00 (improved=False)
# [ILS S30] no improvement (2721.00 >= 2705.00)
# [ILS S30] restart 181/200
# [ILS S30] kicked length=3276.00
# [2-OPT S30R181] start=3276.00
# [2-OPT S30R181] it=50 len=2939.00
# [2-OPT S30R181] final=2885.00
# [3-OPT S30R181] start=2885.00
# [3-OPT S30R181] final=2885.00 (improved=False)
# [ILS S30] no improvement (2885.00 >= 2705.00)
# [ILS S30] restart 182/200
# [ILS S30] kicked length=2941.00
# [2-OPT S30R182] start=2941.00
# [2-OPT S30R182] final=2727.00
# [3-OPT S30R182] start=2727.00
# [3-OPT S30R182] final=2727.00 (improved=False)
# [ILS S30] no improvement (2727.00 >= 2705.00)
# [ILS S30] restart 183/200
# [ILS S30] kicked length=2930.00
# [2-OPT S30R183] start=2930.00
# [2-OPT S30R183] final=2734.00
# [3-OPT S30R183] start=2734.00
# [3-OPT S30R183] final=2734.00 (improved=False)
# [ILS S30] no improvement (2734.00 >= 2705.00)
# [ILS S30] restart 184/200
# [ILS S30] kicked length=3014.00
# [2-OPT S30R184] start=3014.00
# [2-OPT S30R184] final=2737.00
# [3-OPT S30R184] start=2737.00
# [3-OPT S30R184] final=2737.00 (improved=False)
# [ILS S30] no improvement (2737.00 >= 2705.00)
# [ILS S30] restart 185/200
# [ILS S30] kicked length=3010.00
# [2-OPT S30R185] start=3010.00
# [2-OPT S30R185] final=2722.00
# [3-OPT S30R185] start=2722.00
# [3-OPT S30R185] final=2722.00 (improved=False)
# [ILS S30] no improvement (2722.00 >= 2705.00)
# [ILS S30] restart 186/200
# [ILS S30] kicked length=2902.00
# [2-OPT S30R186] start=2902.00
# [2-OPT S30R186] final=2720.00
# [3-OPT S30R186] start=2720.00
# [3-OPT S30R186] final=2720.00 (improved=False)
# [ILS S30] no improvement (2720.00 >= 2705.00)
# [ILS S30] restart 187/200
# [ILS S30] kicked length=3132.00
# [2-OPT S30R187] start=3132.00
# [2-OPT S30R187] final=2706.00
# [3-OPT S30R187] start=2706.00
# [3-OPT S30R187] final=2706.00 (improved=False)
# [ILS S30] no improvement (2706.00 >= 2705.00)
# [ILS S30] restart 188/200
# [ILS S30] kicked length=2769.00
# [2-OPT S30R188] start=2769.00
# [2-OPT S30R188] final=2725.00
# [3-OPT S30R188] start=2725.00
# [3-OPT S30R188] final=2725.00 (improved=False)
# [ILS S30] no improvement (2725.00 >= 2705.00)
# [ILS S30] restart 189/200
# [ILS S30] kicked length=3021.00
# [2-OPT S30R189] start=3021.00
# [2-OPT S30R189] final=2726.00
# [3-OPT S30R189] start=2726.00
# [3-OPT S30R189] final=2726.00 (improved=False)
# [ILS S30] no improvement (2726.00 >= 2705.00)
# [ILS S30] restart 190/200
# [ILS S30] kicked length=3175.00
# [2-OPT S30R190] start=3175.00
# [2-OPT S30R190] final=2741.00
# [3-OPT S30R190] start=2741.00
# [3-OPT S30R190] final=2741.00 (improved=False)
# [ILS S30] no improvement (2741.00 >= 2705.00)
# [ILS S30] restart 191/200
# [ILS S30] kicked length=2902.00
# [2-OPT S30R191] start=2902.00
# [2-OPT S30R191] final=2801.00
# [3-OPT S30R191] start=2801.00
# [3-OPT S30R191] final=2801.00 (improved=False)
# [ILS S30] no improvement (2801.00 >= 2705.00)
# [ILS S30] restart 192/200
# [ILS S30] kicked length=2953.00
# [2-OPT S30R192] start=2953.00
# [2-OPT S30R192] final=2755.00
# [3-OPT S30R192] start=2755.00
# [3-OPT S30R192] final=2755.00 (improved=False)
# [ILS S30] no improvement (2755.00 >= 2705.00)
# [ILS S30] restart 193/200
# [ILS S30] kicked length=3032.00
# [2-OPT S30R193] start=3032.00
# [2-OPT S30R193] final=2811.00
# [3-OPT S30R193] start=2811.00
# [3-OPT S30R193] final=2811.00 (improved=False)
# [ILS S30] no improvement (2811.00 >= 2705.00)
# [ILS S30] restart 194/200
# [ILS S30] kicked length=3039.00
# [2-OPT S30R194] start=3039.00
# [2-OPT S30R194] final=2707.00
# [3-OPT S30R194] start=2707.00
# [3-OPT S30R194] final=2707.00 (improved=False)
# [ILS S30] no improvement (2707.00 >= 2705.00)
# [ILS S30] restart 195/200
# [ILS S30] kicked length=3086.00
# [2-OPT S30R195] start=3086.00
# [2-OPT S30R195] final=2768.00
# [3-OPT S30R195] start=2768.00
# [3-OPT S30R195] final=2768.00 (improved=False)
# [ILS S30] no improvement (2768.00 >= 2705.00)
# [ILS S30] restart 196/200
# [ILS S30] kicked length=2825.00
# [2-OPT S30R196] start=2825.00
# [2-OPT S30R196] final=2715.00
# [3-OPT S30R196] start=2715.00
# [3-OPT S30R196] final=2715.00 (improved=False)
# [ILS S30] no improvement (2715.00 >= 2705.00)
# [ILS S30] restart 197/200
# [ILS S30] kicked length=3127.00
# [2-OPT S30R197] start=3127.00
# [2-OPT S30R197] final=2717.00
# [3-OPT S30R197] start=2717.00
# [3-OPT S30R197] final=2717.00 (improved=False)
# [ILS S30] no improvement (2717.00 >= 2705.00)
# [ILS S30] restart 198/200
# [ILS S30] kicked length=3243.00
# [2-OPT S30R198] start=3243.00
# [2-OPT S30R198] it=50 len=2932.00
# [2-OPT S30R198] final=2932.00
# [3-OPT S30R198] start=2932.00
# [3-OPT S30R198] final=2932.00 (improved=False)
# [ILS S30] no improvement (2932.00 >= 2705.00)
# [ILS S30] restart 199/200
# [ILS S30] kicked length=2950.00
# [2-OPT S30R199] start=2950.00
# [2-OPT S30R199] final=2719.00
# [3-OPT S30R199] start=2719.00
# [3-OPT S30R199] final=2719.00 (improved=False)
# [ILS S30] no improvement (2719.00 >= 2705.00)
# [ILS S30] restart 200/200
# [ILS S30] kicked length=2983.00
# [2-OPT S30R200] start=2983.00
# [2-OPT S30R200] final=2705.00
# [3-OPT S30R200] start=2705.00
# [3-OPT S30R200] final=2705.00 (improved=False)
# [ILS S30] no improvement (2705.00 >= 2705.00)
#
# [RESULT] best length=2613.00
# [CHECK] tour_length(best)=2613.00
#
# ========== FINAL SUMMARY ==========
# TSP best length        : 2613.00
# TTP empty-pack time    : 2613.00
# ===================================
